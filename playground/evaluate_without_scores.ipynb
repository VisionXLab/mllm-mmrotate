# %% [markdown]
# ## 以 rfcos 为例，下载rfcos的权重，用模型进行推理，保存推理的结果

# %%
import os
import mim

from mmengine.config import Config
from mmengine.evaluator import DumpResults
from mmengine.runner import Runner

from mmrotate.utils import register_all_modules
from mmdet.utils import register_all_modules as register_all_modules_mmdet


def monkey_patch_of_collections_typehint_for_mmrotate1x():
    import collections
    from collections.abc import Mapping, Sequence, Iterable
    collections.Mapping = Mapping
    collections.Sequence = Sequence
    collections.Iterable = Iterable

monkey_patch_of_collections_typehint_for_mmrotate1x()

register_all_modules_mmdet(init_default_scope=False)
register_all_modules(init_default_scope=False)

model_name = 'rotated-fcos-le90_r50_fpn_1x_dota'
save_root = './eval_rfcos/'
ckpt_fname = mim.download('mmrotate', [model_name], dest_root=os.path.join(save_root, model_name))[0]

cfg_fpath = os.path.join(save_root, model_name, f'{model_name}.py')
ckpt_fpath = os.path.join(save_root, model_name, ckpt_fname)

cfg = Config.fromfile(cfg_fpath)
cfg.launcher = "none"
cfg.work_dir = save_root
cfg.load_from = ckpt_fpath
cfg.test_dataloader.dataset.data_root = "../playground/data/split_ss_dota"

# test on trainval set
runner = Runner.from_cfg(cfg)
runner.test_evaluator.metrics.append(
    DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_trainval.pkl')))
runner.test()

# test on test set
cfg.test_dataloader.dataset.ann_file = ''
cfg.test_dataloader.dataset.data_prefix = dict(img_path='test/images/')
cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.test_evaluator = dict(
    type='DOTAMetric',
    format_only=True,
    merge_patches=True,
    outfile_prefix=os.path.join(save_root, model_name, 'test'))
runner = Runner.from_cfg(cfg)
runner.test_evaluator.metrics.append(
    DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_test.pkl')))

runner.test()

# %% [markdown]
# ## 查看保存的pkl结果的格式
#
# 目测就是 datasample dump成字典了

# %%
import os
import pickle

model_name = 'rotated-fcos-le90_r50_fpn_1x_dota'
save_root = './eval_rfcos/'
with open(os.path.join(save_root, model_name, 'results_trainval.pkl'), 'rb') as f:
    results_trainval = pickle.load(f)
with open(os.path.join(save_root, model_name, 'results_test.pkl'), 'rb') as f:
    results_test = pickle.load(f)
print(results_trainval[0].keys())
print(results_test[0].keys())
# Out:
# dict_keys(['scale_factor', 'pad_shape', 'batch_input_shape', 'ori_shape', 'img_id', 'img_shape', 'img_path', 'pred_instances', 'ignored_instances', 'gt_instances'])
# dict_keys(['img_path', 'img_shape', 'pad_shape', 'scale_factor', 'img_id', 'ori_shape', 'batch_input_shape', 'pred_instances', 'gt_instances', 'ignored_instances'])

# %% [markdown]
# ## 设定一个初始化评测器的函数

# %%
import os
import torch
from mmengine.fileio import load
from mmengine.evaluator import Evaluator
from mmrotate.evaluation import DOTAMetric

model_name = 'rotated-fcos-le90_r50_fpn_1x_dota'
save_root = './eval_rfcos/'

def prepare_dota_evaluator():
    def monkey_patch_of_collections_typehint_for_mmrotate1x():
        import collections
        from collections.abc import Mapping, Sequence, Iterable
        collections.Mapping = Mapping
        collections.Sequence = Sequence
        collections.Iterable = Iterable

    monkey_patch_of_collections_typehint_for_mmrotate1x()

    evaluator = Evaluator(DOTAMetric(metric="mAP"))
    evaluator.dataset_meta = {
        'classes':
        ('plane', 'baseball-diamond', 'bridge', 'ground-track-field',
            'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
            'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout',
            'harbor', 'swimming-pool', 'helicopter'),
        # palette is a list of color tuples, which is used for visualization.
        'palette': [(165, 42, 42), (189, 183, 107), (0, 255, 0), (255, 0, 0),
                    (138, 43, 226), (255, 128, 0), (255, 0, 255),
                    (0, 255, 255), (255, 193, 193), (0, 51, 153),
                    (255, 250, 205), (0, 139, 139), (255, 255, 0),
                    (147, 116, 116), (0, 0, 255)]
    }
    return evaluator

# %% [markdown]
# ## 该检查点的正常的评测结果

# %%
evaluator = prepare_dota_evaluator()

results_trainval = load(os.path.join(save_root, model_name, 'results_trainval.pkl'))   
evaluator.offline_evaluate(data_samples=results_trainval, chunk_size=128)
# Out:
# 10/25 16:46:51 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 16:46:54,270] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:46:54,361] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:46:54,403] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:46:54,411] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 16:47:36 - mmengine - INFO -
# +--------------------+-------+--------+--------+-------+
# | class              | gts   | dets   | recall | ap    |
# +--------------------+-------+--------+--------+-------+
# | plane              | 18788 | 41274  | 0.971  | 0.904 |
# | baseball-diamond   | 1087  | 20502  | 0.947  | 0.804 |
# | bridge             | 4183  | 74732  | 0.819  | 0.602 |
# | ground-track-field | 733   | 15477  | 0.809  | 0.660 |
# | small-vehicle      | 58868 | 289672 | 0.910  | 0.803 |
# | large-vehicle      | 43075 | 233429 | 0.942  | 0.851 |
# | ship               | 76153 | 178456 | 0.920  | 0.874 |
# | tennis-court       | 5923  | 18764  | 0.985  | 0.907 |
# | basketball-court   | 1180  | 18171  | 0.971  | 0.872 |
# | storage-tank       | 13670 | 87152  | 0.844  | 0.775 |
# | soccer-ball-field  | 827   | 19432  | 0.920  | 0.748 |
# | roundabout         | 973   | 21765  | 0.921  | 0.778 |
# | harbor             | 15468 | 86840  | 0.829  | 0.739 |
# | swimming-pool      | 3836  | 19875  | 0.946  | 0.849 |
# | helicopter         | 1189  | 13983  | 0.951  | 0.882 |
# +--------------------+-------+--------+--------+-------+
# | mAP                |       |        |        | 0.803 |
# +--------------------+-------+--------+--------+-------+
# {'dota/mAP': 0.8031923174858093, 'dota/AP50': 0.803}

# %% [markdown]
# ## 所有score强制为1的时候的评测结果

# %%
evaluator = prepare_dota_evaluator()

results_trainval = load(os.path.join(save_root, model_name, 'results_trainval.pkl'))   
for res in results_trainval:
    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
evaluator.offline_evaluate(data_samples=results_trainval, chunk_size=128)
# Out:
# 10/25 16:53:36 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 16:53:38,885] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:53:39,094] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:53:39,140] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 16:53:39,153] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 16:54:22 - mmengine - INFO -
# +--------------------+-------+--------+--------+-------+
# | class              | gts   | dets   | recall | ap    |
# +--------------------+-------+--------+--------+-------+
# | plane              | 18788 | 41274  | 0.971  | 0.425 |
# | baseball-diamond   | 1087  | 20502  | 0.947  | 0.048 |
# | bridge             | 4183  | 74732  | 0.819  | 0.038 |
# | ground-track-field | 733   | 15477  | 0.809  | 0.120 |
# | small-vehicle      | 58868 | 289672 | 0.910  | 0.198 |
# | large-vehicle      | 43075 | 233429 | 0.942  | 0.169 |
# | ship               | 76153 | 178456 | 0.920  | 0.391 |
# | tennis-court       | 5923  | 18764  | 0.985  | 0.350 |
# | basketball-court   | 1180  | 18171  | 0.971  | 0.062 |
# | storage-tank       | 13670 | 87152  | 0.844  | 0.116 |
# | soccer-ball-field  | 827   | 19432  | 0.920  | 0.045 |
# | roundabout         | 973   | 21765  | 0.921  | 0.047 |
# | harbor             | 15468 | 86840  | 0.829  | 0.125 |
# | swimming-pool      | 3836  | 19875  | 0.946  | 0.180 |
# | helicopter         | 1189  | 13983  | 0.951  | 0.094 |
# +--------------------+-------+--------+--------+-------+
# | mAP                |       |        |        | 0.161 |
# +--------------------+-------+--------+--------+-------+
# {'dota/mAP': 0.16053149104118347, 'dota/AP50': 0.161}

# %% [markdown]
# ## 用score设定阈值过滤一遍后，把剩下的score设成1的结果

# %%
import pandas
results = {}
for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
    for hack_score in [True, False]:
        print("".join(["="*10, f" score threshold={threshold} ", "="*10]))

        evaluator = prepare_dota_evaluator()

        results_trainval = load(os.path.join(save_root, model_name, 'results_trainval.pkl'))   
        for res in results_trainval:
            keep = res["pred_instances"]["scores"] > threshold
            res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
            res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
            res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
            
            if hack_score:
                res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
                
        map = evaluator.offline_evaluate(data_samples=results_trainval, chunk_size=128)['dota/mAP']
        
        if threshold not in results:
            results[threshold] = {}
        if hack_score:
            results[threshold]["score=1"] = map
        else:
            results[threshold]["score=score"] = map
            
print(pandas.DataFrame.from_dict(results).T)
# Out:
# ========== score=0.1 ==========
# 10/25 17:12:54 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:12:57,466] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:12:57,602] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:12:57,713] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:12:57,741] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:13:36 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.777 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.257 |
# | bridge             | 4183  | 10496 | 0.787  | 0.229 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.180 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.504 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.560 |
# | ship               | 76153 | 89991 | 0.913  | 0.730 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.770 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.470 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.558 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.281 |
# | roundabout         | 973   | 3012  | 0.897  | 0.274 |
# | harbor             | 15468 | 22990 | 0.818  | 0.457 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.544 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.508 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.473 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.1 ==========
# 10/25 17:14:01 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:14:03,858] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:14:04,039] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:14:04,039] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:14:04,044] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:14:42 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.904 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.804 |
# | bridge             | 4183  | 10496 | 0.787  | 0.582 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.642 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.764 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.851 |
# | ship               | 76153 | 89991 | 0.913  | 0.874 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.907 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.872 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.775 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.748 |
# | roundabout         | 973   | 3012  | 0.897  | 0.756 |
# | harbor             | 15468 | 22990 | 0.818  | 0.739 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.849 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.882 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.797 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.2 ==========
# 10/25 17:15:07 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:15:09,893] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:15:10,017] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:15:10,046] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:15:10,110] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:15:47 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.853 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.543 |
# | bridge             | 4183  | 4779  | 0.675  | 0.379 |
# | ground-track-field | 733   | 942   | 0.723  | 0.425 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.667 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.678 |
# | ship               | 76153 | 75960 | 0.881  | 0.736 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.861 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.738 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.634 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.481 |
# | roundabout         | 973   | 1512  | 0.871  | 0.504 |
# | harbor             | 15468 | 15520 | 0.768  | 0.580 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.636 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.695 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.627 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.2 ==========
# 10/25 17:16:10 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:16:13,314] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:16:13,530] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:16:13,550] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:16:13,560] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:16:49 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.904 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.804 |
# | bridge             | 4183  | 4779  | 0.675  | 0.531 |
# | ground-track-field | 733   | 942   | 0.723  | 0.642 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.764 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.783 |
# | ship               | 76153 | 75960 | 0.881  | 0.797 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.907 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.872 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.710 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.723 |
# | roundabout         | 973   | 1512  | 0.871  | 0.756 |
# | harbor             | 15468 | 15520 | 0.768  | 0.676 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.783 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.810 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.764 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.25 ==========
# 10/25 17:17:13 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:17:16,297] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:17:16,387] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:17:16,540] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:17:16,572] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:17:51 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18557 | 0.936  | 0.868 |
# | baseball-diamond   | 1087  | 1443  | 0.903  | 0.630 |
# | bridge             | 4183  | 3529  | 0.577  | 0.403 |
# | ground-track-field | 733   | 671   | 0.636  | 0.474 |
# | small-vehicle      | 58868 | 53141 | 0.759  | 0.631 |
# | large-vehicle      | 43075 | 40110 | 0.811  | 0.727 |
# | ship               | 76153 | 70008 | 0.842  | 0.759 |
# | tennis-court       | 5923  | 6001  | 0.968  | 0.875 |
# | basketball-court   | 1180  | 1260  | 0.895  | 0.712 |
# | storage-tank       | 13670 | 10718 | 0.703  | 0.666 |
# | soccer-ball-field  | 827   | 951   | 0.786  | 0.528 |
# | roundabout         | 973   | 1248  | 0.849  | 0.574 |
# | harbor             | 15468 | 12705 | 0.687  | 0.536 |
# | swimming-pool      | 3836  | 4123  | 0.864  | 0.663 |
# | helicopter         | 1189  | 1187  | 0.881  | 0.743 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.653 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.25 ==========
# 10/25 17:18:14 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:18:17,629] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:18:17,807] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:18:17,881] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:18:17,902] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:18:54 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18557 | 0.936  | 0.904 |
# | baseball-diamond   | 1087  | 1443  | 0.903  | 0.804 |
# | bridge             | 4183  | 3529  | 0.577  | 0.470 |
# | ground-track-field | 733   | 671   | 0.636  | 0.588 |
# | small-vehicle      | 58868 | 53141 | 0.759  | 0.692 |
# | large-vehicle      | 43075 | 40110 | 0.811  | 0.783 |
# | ship               | 76153 | 70008 | 0.842  | 0.797 |
# | tennis-court       | 5923  | 6001  | 0.968  | 0.907 |
# | basketball-court   | 1180  | 1260  | 0.895  | 0.796 |
# | storage-tank       | 13670 | 10718 | 0.703  | 0.710 |
# | soccer-ball-field  | 827   | 951   | 0.786  | 0.663 |
# | roundabout         | 973   | 1248  | 0.849  | 0.756 |
# | harbor             | 15468 | 12705 | 0.687  | 0.600 |
# | swimming-pool      | 3836  | 4123  | 0.864  | 0.783 |
# | helicopter         | 1189  | 1187  | 0.881  | 0.810 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.738 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.3 ==========
# 10/25 17:19:17 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:19:19,660] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:19:19,689] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:19:19,922] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:19:19,996] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:19:54 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18056 | 0.925  | 0.879 |
# | baseball-diamond   | 1087  | 1247  | 0.869  | 0.652 |
# | bridge             | 4183  | 2509  | 0.455  | 0.353 |
# | ground-track-field | 733   | 488   | 0.557  | 0.474 |
# | small-vehicle      | 58868 | 46720 | 0.701  | 0.656 |
# | large-vehicle      | 43075 | 34310 | 0.720  | 0.663 |
# | ship               | 76153 | 62818 | 0.776  | 0.690 |
# | tennis-court       | 5923  | 5838  | 0.958  | 0.888 |
# | basketball-court   | 1180  | 1132  | 0.847  | 0.742 |
# | storage-tank       | 13670 | 9654  | 0.659  | 0.603 |
# | soccer-ball-field  | 827   | 737   | 0.680  | 0.511 |
# | roundabout         | 973   | 1054  | 0.805  | 0.635 |
# | harbor             | 15468 | 9971  | 0.572  | 0.496 |
# | swimming-pool      | 3836  | 3693  | 0.821  | 0.706 |
# | helicopter         | 1189  | 1069  | 0.842  | 0.780 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.649 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.3 ==========
# 10/25 17:20:17 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:20:20,621] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:20:20,664] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:20:20,894] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:20:20,897] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:20:56 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18056 | 0.925  | 0.904 |
# | baseball-diamond   | 1087  | 1247  | 0.869  | 0.741 |
# | bridge             | 4183  | 2509  | 0.455  | 0.404 |
# | ground-track-field | 733   | 488   | 0.557  | 0.520 |
# | small-vehicle      | 58868 | 46720 | 0.701  | 0.692 |
# | large-vehicle      | 43075 | 34310 | 0.720  | 0.703 |
# | ship               | 76153 | 62818 | 0.776  | 0.712 |
# | tennis-court       | 5923  | 5838  | 0.958  | 0.907 |
# | basketball-court   | 1180  | 1132  | 0.847  | 0.796 |
# | storage-tank       | 13670 | 9654  | 0.659  | 0.628 |
# | soccer-ball-field  | 827   | 737   | 0.680  | 0.594 |
# | roundabout         | 973   | 1054  | 0.805  | 0.756 |
# | harbor             | 15468 | 9971  | 0.572  | 0.521 |
# | swimming-pool      | 3836  | 3693  | 0.821  | 0.783 |
# | helicopter         | 1189  | 1069  | 0.842  | 0.810 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.698 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.35 ==========
# 10/25 17:21:20 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:21:22,677] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:21:22,844] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:21:22,894] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:21:22,976] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:21:55 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 17580 | 0.910  | 0.887 |
# | baseball-diamond   | 1087  | 1084  | 0.809  | 0.686 |
# | bridge             | 4183  | 1745  | 0.343  | 0.317 |
# | ground-track-field | 733   | 372   | 0.454  | 0.426 |
# | small-vehicle      | 58868 | 38778 | 0.605  | 0.594 |
# | large-vehicle      | 43075 | 28071 | 0.606  | 0.599 |
# | ship               | 76153 | 54413 | 0.683  | 0.613 |
# | tennis-court       | 5923  | 5690  | 0.943  | 0.896 |
# | basketball-court   | 1180  | 1017  | 0.782  | 0.674 |
# | storage-tank       | 13670 | 8712  | 0.608  | 0.614 |
# | soccer-ball-field  | 827   | 577   | 0.588  | 0.466 |
# | roundabout         | 973   | 936   | 0.768  | 0.604 |
# | harbor             | 15468 | 7657  | 0.456  | 0.427 |
# | swimming-pool      | 3836  | 3224  | 0.748  | 0.659 |
# | helicopter         | 1189  | 929   | 0.759  | 0.716 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.612 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.35 ==========
# 10/25 17:22:18 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:22:21,259] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:22:21,489] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:22:21,497] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:22:21,606] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:22:52 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 17580 | 0.910  | 0.904 |
# | baseball-diamond   | 1087  | 1084  | 0.809  | 0.741 |
# | bridge             | 4183  | 1745  | 0.343  | 0.332 |
# | ground-track-field | 733   | 372   | 0.454  | 0.441 |
# | small-vehicle      | 58868 | 38778 | 0.605  | 0.612 |
# | large-vehicle      | 43075 | 28071 | 0.606  | 0.621 |
# | ship               | 76153 | 54413 | 0.683  | 0.626 |
# | tennis-court       | 5923  | 5690  | 0.943  | 0.907 |
# | basketball-court   | 1180  | 1017  | 0.782  | 0.714 |
# | storage-tank       | 13670 | 8712  | 0.608  | 0.628 |
# | soccer-ball-field  | 827   | 577   | 0.588  | 0.519 |
# | roundabout         | 973   | 936   | 0.768  | 0.687 |
# | harbor             | 15468 | 7657  | 0.456  | 0.438 |
# | swimming-pool      | 3836  | 3224  | 0.748  | 0.704 |
# | helicopter         | 1189  | 929   | 0.759  | 0.723 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.640 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.4 ==========
# 10/25 17:23:15 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:23:17,745] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:23:18,054] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:23:18,068] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:23:18,113] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:23:46 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 16975 | 0.886  | 0.804 |
# | baseball-diamond   | 1087  | 914   | 0.716  | 0.633 |
# | bridge             | 4183  | 1123  | 0.232  | 0.249 |
# | ground-track-field | 733   | 270   | 0.351  | 0.354 |
# | small-vehicle      | 58868 | 28245 | 0.453  | 0.435 |
# | large-vehicle      | 43075 | 22154 | 0.491  | 0.439 |
# | ship               | 76153 | 44318 | 0.563  | 0.531 |
# | tennis-court       | 5923  | 5543  | 0.924  | 0.900 |
# | basketball-court   | 1180  | 889   | 0.704  | 0.688 |
# | storage-tank       | 13670 | 7798  | 0.553  | 0.534 |
# | soccer-ball-field  | 827   | 443   | 0.485  | 0.421 |
# | roundabout         | 973   | 828   | 0.714  | 0.635 |
# | harbor             | 15468 | 5701  | 0.349  | 0.350 |
# | swimming-pool      | 3836  | 2643  | 0.646  | 0.604 |
# | helicopter         | 1189  | 755   | 0.625  | 0.632 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.547 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.4 ==========
# 10/25 17:24:08 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:24:10,794] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:24:10,965] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:24:11,058] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:24:11,075] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:24:39 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 16975 | 0.886  | 0.815 |
# | baseball-diamond   | 1087  | 914   | 0.716  | 0.667 |
# | bridge             | 4183  | 1123  | 0.232  | 0.256 |
# | ground-track-field | 733   | 270   | 0.351  | 0.357 |
# | small-vehicle      | 58868 | 28245 | 0.453  | 0.443 |
# | large-vehicle      | 43075 | 22154 | 0.491  | 0.449 |
# | ship               | 76153 | 44318 | 0.563  | 0.538 |
# | tennis-court       | 5923  | 5543  | 0.924  | 0.907 |
# | basketball-court   | 1180  | 889   | 0.704  | 0.714 |
# | storage-tank       | 13670 | 7798  | 0.553  | 0.541 |
# | soccer-ball-field  | 827   | 443   | 0.485  | 0.437 |
# | roundabout         | 973   | 828   | 0.714  | 0.687 |
# | harbor             | 15468 | 5701  | 0.349  | 0.353 |
# | swimming-pool      | 3836  | 2643  | 0.646  | 0.621 |
# | helicopter         | 1189  | 755   | 0.625  | 0.634 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.561 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.5 ==========
# 10/25 17:25:00 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:25:03,059] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:03,165] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:04,129] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:04,518] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:25:26 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 15102 | 0.796  | 0.722 |
# | baseball-diamond   | 1087  | 475   | 0.397  | 0.344 |
# | bridge             | 4183  | 348   | 0.079  | 0.091 |
# | ground-track-field | 733   | 90    | 0.121  | 0.181 |
# | small-vehicle      | 58868 | 7449  | 0.124  | 0.180 |
# | large-vehicle      | 43075 | 12052 | 0.276  | 0.270 |
# | ship               | 76153 | 22100 | 0.286  | 0.270 |
# | tennis-court       | 5923  | 5255  | 0.881  | 0.814 |
# | basketball-court   | 1180  | 643   | 0.535  | 0.539 |
# | storage-tank       | 13670 | 5826  | 0.420  | 0.450 |
# | soccer-ball-field  | 827   | 223   | 0.258  | 0.265 |
# | roundabout         | 973   | 603   | 0.563  | 0.506 |
# | harbor             | 15468 | 2039  | 0.127  | 0.179 |
# | swimming-pool      | 3836  | 1208  | 0.306  | 0.357 |
# | helicopter         | 1189  | 103   | 0.087  | 0.091 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.351 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.5 ==========
# 10/25 17:25:46 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:25:49,618] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:49,782] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:49,854] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:25:49,856] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:26:12 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 15102 | 0.796  | 0.725 |
# | baseball-diamond   | 1087  | 475   | 0.397  | 0.344 |
# | bridge             | 4183  | 348   | 0.079  | 0.091 |
# | ground-track-field | 733   | 90    | 0.121  | 0.181 |
# | small-vehicle      | 58868 | 7449  | 0.124  | 0.180 |
# | large-vehicle      | 43075 | 12052 | 0.276  | 0.271 |
# | ship               | 76153 | 22100 | 0.286  | 0.271 |
# | tennis-court       | 5923  | 5255  | 0.881  | 0.817 |
# | basketball-court   | 1180  | 643   | 0.535  | 0.542 |
# | storage-tank       | 13670 | 5826  | 0.420  | 0.452 |
# | soccer-ball-field  | 827   | 223   | 0.258  | 0.268 |
# | roundabout         | 973   | 603   | 0.563  | 0.530 |
# | harbor             | 15468 | 2039  | 0.127  | 0.179 |
# | swimming-pool      | 3836  | 1208  | 0.306  | 0.359 |
# | helicopter         | 1189  | 103   | 0.087  | 0.091 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.353 |
# +--------------------+-------+-------+--------+-------+
# ========== score=0.7 ==========
# 10/25 17:26:32 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:26:35,449] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:26:35,602] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:26:35,643] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:26:35,783] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:26:53 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score=0.7 ==========
# 10/25 17:27:13 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-25 17:27:16,274] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:27:16,318] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:27:16,398] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-25 17:27:16,418] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/25 17:27:34 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.636 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
#        score=1  score=score
# 0.10  0.473128     0.796567
# 0.20  0.627359     0.764042
# 0.25  0.652667     0.737540
# 0.30  0.648651     0.698156
# 0.35  0.611792     0.639825
# 0.40  0.547297     0.561349
# 0.50  0.350561     0.353396
# 0.70  0.090796     0.090824

# %% [markdown]
# 结论：
# 1. 在有score的情况下，设定阈值过滤掉低分的目标会导致掉点，mAP似乎会容忍低分的目标作为一些gt的填补，是否是会更在乎recall而容忍低分和虚警？
# 2. 如果score置成1的话，不应该不进行任何筛选，但也不应该进行过于严格的筛选
# 3. 这里面实验结果最好的是 0.25 的阈值下
#
# 我目前的印象里，score会影响的似乎主要是最一开始的一个sort（还要再回一下），全给1的话说不定这个sort就会摆烂或者相当于随机，这可能扰乱了map的sort导致了掉点
# 重要的是，这说明很可能这个下降的程度要取决于sort被影响的程度，或者说，这个掉点的量很可能是有随机性的
# todo：后面可以探索一下这个随机性对于map的值的影响，试试看能不能衡量出一个平均值和方差看看这个掉点大概是啥样的，或者说还有没有可能会有小丑涨点的状况

# %% [markdown]
# ## 对test也做了过滤和置1的操作，用trainval里效果最好的那个阈值

# %%
model_name = 'rotated-fcos-le90_r50_fpn_1x_dota'

evaluator = Evaluator(
    DOTAMetric(format_only=True, 
               merge_patches=True, 
               outfile_prefix=os.path.join(save_root, model_name, 'test_0.2above-score=1'))
)

evaluator.dataset_meta = {
    'classes':
    ('plane', 'baseball-diamond', 'bridge', 'ground-track-field',
        'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
        'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout',
        'harbor', 'swimming-pool', 'helicopter'),
    # palette is a list of color tuples, which is used for visualization.
    'palette': [(165, 42, 42), (189, 183, 107), (0, 255, 0), (255, 0, 0),
                (138, 43, 226), (255, 128, 0), (255, 0, 255),
                (0, 255, 255), (255, 193, 193), (0, 51, 153),
                (255, 250, 205), (0, 139, 139), (255, 255, 0),
                (147, 116, 116), (0, 0, 255)]
}

results_test = load(os.path.join(save_root, model_name, 'results_test.pkl'))   
for res in results_test:
    keep = res["pred_instances"]["scores"] > 0.25
    res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
    res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
    res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
    
evaluator.offline_evaluate(data_samples=results_test, chunk_size=128)
# Out:
# 10/25 17:37:28 - mmengine - INFO - The submission file save at ./eval_rfcos/rotated-fcos-le90_r50_fpn_1x_dota/test_0.2above-score=1/test_0.2above-score=1.zip
# {}

# %% [markdown]
# 送给 dota evaluation 查看实验结果
#
# rotated fcos baseline:
#
# ```python
# mAP: 0.7123079788356041
# ap of each class: plane:0.8916182684809109, baseball-diamond:0.7191643582273857, bridge:0.48042269222436457, ground-track-field:0.6203818542325392, small-vehicle:0.7925815334022364, large-vehicle:0.7362002200598536, ship:0.8573985143996952, tennis-court:0.9090227613465995, basketball-court:0.8066071522146891, storage-tank:0.8431662211826575, soccer-ball-field:0.5939472468454459, roundabout:0.6290973735033039, harbor:0.6204171011301067, swimming-pool:0.6981793541941752, helicopter:0.48641503109009765
# COCO style result:
# AP50: 0.7123079788356041
# AP75: 0.3700845169417177
# mAP: 0.3940536185583186
# ```
#
# Rotated FCOS 的测试 设定了0.25的score阈值，并把剩下的score全重置为1
#
# ```python
# mAP: 0.5891609083502711
# ap of each class: plane:0.7450649608789142, baseball-diamond:0.6488683433830279, bridge:0.3317678182505998, ground-track-field:0.4458891577699675, small-vehicle:0.6044638167353917, large-vehicle:0.5844260350465345, ship:0.7432801107048516, tennis-court:0.8874432749891452, basketball-court:0.7096262298134566, storage-tank:0.6887741046831954, soccer-ball-field:0.45957920409052394, roundabout:0.46982105429960336, harbor:0.49046957808843145, swimming-pool:0.5657295197554624, helicopter:0.4622104167649613
# COCO style result:
# AP50: 0.5891609083502711
# AP75: 0.27821359548046143
# mAP: 0.31064270094235924
# ```

# %% [markdown]
# ## 尝试把置1的操作换成seed不同的randomness

# %%
import pandas
import random
results = {}
for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
    for hack_score in ["score", "1", 
                       "rnd:42", "rnd:666", "rnd:6666", "rnd:66666", "rnd:666666", "rnd:2024", 
                       "rnd:9968", "rnd:0", "rnd:1", "rnd:123"]:
        print("".join(["="*10, f" score threshold={threshold} ", "="*10]))

        evaluator = prepare_dota_evaluator()

        results_trainval = load(os.path.join(save_root, model_name, 'results_trainval.pkl'))   
        for res in results_trainval:
            keep = res["pred_instances"]["scores"] > threshold
            res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
            res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
            res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
            
            if hack_score == "1":
                res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
            elif hack_score.startswith("rnd:"):
                seed = hack_score.split(":")[-1]
                random.seed(seed)
                torch.manual_seed(seed)
                res["pred_instances"]["scores"] = torch.rand_like(res["pred_instances"]["scores"])
                
        map = evaluator.offline_evaluate(data_samples=results_trainval, chunk_size=128)['dota/mAP']
        
        if threshold not in results:
            results[threshold] = {}
        results[threshold][hack_score] = map
            
    random_values = [v for k, v in results[threshold].items() if k.startswith("rnd:")]
    results[threshold]["rnd:max"] = max(random_values)
    results[threshold]["rnd:min"] = min(random_values)
    results[threshold]["rnd:mean"] = sum(random_values) / len(random_values)
            
print(pandas.DataFrame.from_dict(results).T)
# Out:
# ========== score threshold=0.1 ==========
# 10/29 16:37:36 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:37:39,709] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:37:39,879] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:37:39,889] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:37:39,922] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:38:20 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.904 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.804 |
# | bridge             | 4183  | 10496 | 0.787  | 0.582 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.642 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.764 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.851 |
# | ship               | 76153 | 89991 | 0.913  | 0.874 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.907 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.872 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.775 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.748 |
# | roundabout         | 973   | 3012  | 0.897  | 0.756 |
# | harbor             | 15468 | 22990 | 0.818  | 0.739 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.849 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.882 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.797 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 10/29 16:38:43 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:38:46,975] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:38:47,006] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:38:47,035] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:38:47,041] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:39:32 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.777 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.257 |
# | bridge             | 4183  | 10496 | 0.787  | 0.229 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.180 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.504 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.560 |
# | ship               | 76153 | 89991 | 0.913  | 0.730 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.770 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.470 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.558 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.281 |
# | roundabout         | 973   | 3012  | 0.897  | 0.274 |
# | harbor             | 15468 | 22990 | 0.818  | 0.457 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.544 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.508 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.473 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 10/29 16:39:59 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:40:02,097] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:40:02,367] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:40:02,459] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:40:02,549] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:40:42 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.769 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.272 |
# | bridge             | 4183  | 10496 | 0.787  | 0.262 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.224 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.467 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.571 |
# | ship               | 76153 | 89991 | 0.913  | 0.710 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.804 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.501 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.543 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.334 |
# | roundabout         | 973   | 3012  | 0.897  | 0.348 |
# | harbor             | 15468 | 22990 | 0.818  | 0.501 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.520 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.458 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.486 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 10/29 16:41:09 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:41:12,687] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:41:12,959] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:41:13,003] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:41:13,014] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:41:54 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.761 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.268 |
# | bridge             | 4183  | 10496 | 0.787  | 0.262 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.215 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.454 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.557 |
# | ship               | 76153 | 89991 | 0.913  | 0.732 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.779 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.437 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.533 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.288 |
# | roundabout         | 973   | 3012  | 0.897  | 0.330 |
# | harbor             | 15468 | 22990 | 0.818  | 0.451 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.494 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.490 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.470 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 10/29 16:42:20 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:42:24,101] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:42:24,285] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:42:24,392] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:42:24,461] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:43:08 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.777 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.258 |
# | bridge             | 4183  | 10496 | 0.787  | 0.243 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.195 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.500 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.595 |
# | ship               | 76153 | 89991 | 0.913  | 0.725 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.786 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.448 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.520 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.285 |
# | roundabout         | 973   | 3012  | 0.897  | 0.272 |
# | harbor             | 15468 | 22990 | 0.818  | 0.507 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.542 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.480 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0
|
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.480 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 10/29 16:50:58 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:51:01,557] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:51:01,781] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:51:01,802] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:51:01,827] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:51:44 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 21623 | 0.960  | 0.760 |
# | baseball-diamond   | 1087  | 3720  | 0.940  | 0.259 |
# | bridge             | 4183  | 10496 | 0.787  | 0.250 |
# | ground-track-field | 733   | 2450  | 0.799  | 0.204 |
# | small-vehicle      | 58868 | 94304 | 0.885  | 0.494 |
# | large-vehicle      | 43075 | 65009 | 0.920  | 0.556 |
# | ship               | 76153 | 89991 | 0.913  | 0.731 |
# | tennis-court       | 5923  | 6937  | 0.981  | 0.769 |
# | basketball-court   | 1180  | 2458  | 0.960  | 0.422 |
# | storage-tank       | 13670 | 18124 | 0.820  | 0.514 |
# | soccer-ball-field  | 827   | 2708  | 0.901  | 0.279 |
# | roundabout         | 973   | 3012  | 0.897  | 0.298 |
# | harbor             | 15468 | 22990 | 0.818  | 0.494 |
# | swimming-pool      | 3836  | 6620  | 0.932  | 0.494 |
# | helicopter         | 1189  | 2360  | 0.930  | 0.442 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.464 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:52:06 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:52:09,597] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:52:09,605] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:52:09,626] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:52:09,694] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:52:50 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.904 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.804 |
# | bridge             | 4183  | 4779  | 0.675  | 0.531 |
# | ground-track-field | 733   | 942   | 0.723  | 0.642 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.764 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.783 |
# | ship               | 76153 | 75960 | 0.881  | 0.797 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.907 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.872 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.710 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.723 |
# | roundabout         | 973   | 1512  | 0.871  | 0.756 |
# | harbor             | 15468 | 15520 | 0.768  | 0.676 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.783 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.810 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.764 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:53:13 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:53:16,284] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:53:16,375] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:53:16,398] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:53:16,467] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:53:57 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.853 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.543 |
# | bridge             | 4183  | 4779  | 0.675  | 0.379 |
# | ground-track-field | 733   | 942   | 0.723  | 0.425 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.667 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.678 |
# | ship               | 76153 | 75960 | 0.881  | 0.736 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.861 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.738 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.634 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.481 |
# | roundabout         | 973   | 1512  | 0.871  | 0.504 |
# | harbor             | 15468 | 15520 | 0.768  | 0.580 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.636 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.695 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.627 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:54:22 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:54:26,027] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:54:26,108] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:54:26,110] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:54:26,148] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:55:06 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.849 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.568 |
# | bridge             | 4183  | 4779  | 0.675  | 0.388 |
# | ground-track-field | 733   | 942   | 0.723  | 0.435 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.647 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.696 |
# | ship               | 76153 | 75960 | 0.881  | 0.733 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.866 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.736 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.628 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.532 |
# | roundabout         | 973   | 1512  | 0.871  | 0.549 |
# | harbor             | 15468 | 15520 | 0.768  | 0.597 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.641 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.676 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.636 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:55:33 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:55:36,922] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:55:37,033] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:55:37,068] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:55:37,109] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:56:19 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.852 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.579 |
# | bridge             | 4183  | 4779  | 0.675  | 0.393 |
# | ground-track-field | 733   | 942   | 0.723  | 0.500 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.662 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.674 |
# | ship               | 76153 | 75960 | 0.881  | 0.737 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.860 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.728 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.632 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.527 |
# | roundabout         | 973   | 1512  | 0.871  | 0.555 |
# | harbor             | 15468 | 15520 | 0.768  | 0.557 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.615 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.686 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.637 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:56:44 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:56:48,125] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:56:48,195] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:56:48,231] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:56:48,253] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:57:29 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.853 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.555 |
# | bridge             | 4183  | 4779  | 0.675  | 0.386 |
# | ground-track-field | 733   | 942   | 0.723  | 0.436 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.663 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.691 |
# | ship               | 76153 | 75960 | 0.881  | 0.735 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.867 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.745 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.631 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.482 |
# | roundabout         | 973   | 1512  | 0.871  | 0.521 |
# | harbor             | 15468 | 15520 | 0.768  | 0.586 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.637 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.679 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.631 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:57:55 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:57:58,101] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:57:58,427] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:57:58,439] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:57:58,449] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:58:38 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.855 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.582 |
# | bridge             | 4183  | 4779  | 0.675  | 0.376 |
# | ground-track-field | 733   | 942   | 0.723  | 0.416 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.664 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.696 |
# | ship               | 76153 | 75960 | 0.881  | 0.736 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.853 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.741 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.643 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.512 |
# | roundabout         | 973   | 1512  | 0.871  | 0.458 |
# | harbor             | 15468 | 15520 | 0.768  | 0.583 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.644 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.680 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.629 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 16:59:04 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 16:59:08,206] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:59:08,328] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:59:08,338] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 16:59:08,360] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 16:59:49 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.851 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.577 |
# | bridge             | 4183  | 4779  | 0.675  | 0.427 |
# | ground-track-field | 733   | 942   | 0.723  | 0.477 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.662 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.691 |
# | ship               | 76153 | 75960 | 0.881  | 0.734 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.869 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.709 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.627 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.518 |
# | roundabout         | 973   | 1512  | 0.871  | 0.528 |
# | harbor             | 15468 | 15520 | 0.768  | 0.576 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.635 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.687 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.638 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 17:00:15 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:00:18,647] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:00:18,657] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:00:18,667] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:00:18,843] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:01:01 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.848 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.583 |
# | bridge             | 4183  | 4779  | 0.675  | 0.391 |
# | ground-track-field | 733   | 942   | 0.723  | 0.431 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.646 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.691 |
# | ship               | 76153 | 75960 | 0.881  | 0.735 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.865 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.728 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.630 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.513 |
# | roundabout         | 973   | 1512  | 0.871  | 0.496 |
# | harbor             | 15468 | 15520 | 0.768  | 0.569 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.642 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.675 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.630 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 17:01:27 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:01:30,489] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:01:30,850] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:01:30,950] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:01:30,962] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:02:11 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.851 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.564 |
# | bridge             | 4183  | 4779  | 0.675  | 0.391 |
# | ground-track-field | 733   | 942   | 0.723  | 0.442 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.665 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.690 |
# | ship               | 76153 | 75960 | 0.881  | 0.735 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.864 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.727 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.632 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.516 |
# | roundabout         | 973   | 1512  | 0.871  | 0.523 |
# | harbor             | 15468 | 15520 | 0.768  | 0.586 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.621 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.694 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.633 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 17:02:36 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:02:40,080] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:02:40,491] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:02:40,509] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:02:40,542] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:03:20 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.845 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.569 |
# | bridge             | 4183  | 4779  | 0.675  | 0.386 |
# | ground-track-field | 733   | 942   | 0.723  | 0.442 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.663 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.690 |
# | ship               | 76153 | 75960 | 0.881  | 0.735 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.862 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.709 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.632 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.501 |
# | roundabout         | 973   | 1512  | 0.871  | 0.550 |
# | harbor             | 15468 | 15520 | 0.768  | 0.579 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.636 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.683 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.632 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 17:03:45 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:03:48,956] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:03:49,024] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:03:49,087] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:03:49,098] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:04:33 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.852 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.537 |
# | bridge             | 4183  | 4779  | 0.675  | 0.399 |
# | ground-track-field | 733   | 942   | 0.723  | 0.481 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.663 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.692 |
# | ship               | 76153 | 75960 | 0.881  | 0.736 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.862 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.725 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.632 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.515 |
# | roundabout         | 973   | 1512  | 0.871  | 0.527 |
# | harbor             | 15468 | 15520 | 0.768  | 0.563 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.613 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.682 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.632 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.2 ==========
# 10/29 17:04:59 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:05:03,435] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:05:03,770] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:05:03,772] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:05:03,832] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:05:45 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19130 | 0.946  | 0.852 |
# | baseball-diamond   | 1087  | 1702  | 0.921  | 0.573 |
# | bridge             | 4183  | 4779  | 0.675  | 0.384 |
# | ground-track-field | 733   | 942   | 0.723  | 0.433 |
# | small-vehicle      | 58868 | 60454 | 0.805  | 0.662 |
# | large-vehicle      | 43075 | 45614 | 0.870  | 0.689 |
# | ship               | 76153 | 75960 | 0.881  | 0.730 |
# | tennis-court       | 5923  | 6148  | 0.974  | 0.862 |
# | basketball-court   | 1180  | 1404  | 0.922  | 0.735 |
# | storage-tank       | 13670 | 12149 | 0.749  | 0.639 |
# | soccer-ball-field  | 827   | 1211  | 0.846  | 0.484 |
# | roundabout         | 973   | 1512  | 0.871  | 0.501 |
# | harbor             | 15468 | 15520 | 0.768  | 0.579 |
# | swimming-pool      | 3836  | 4601  | 0.894  | 0.625 |
# | helicopter         | 1189  | 1334  | 0.898  | 0.677 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.628 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.25 ==========
# 10/29 17:06:07 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:06:10,735] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:06:10,970] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:06:10,980] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:06:10,994] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:06:50 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18557 | 0.936  | 0.904 |
# | baseball-diamond   | 1087  | 1443  | 0.903  | 0.804 |
# | bridge             | 4183  | 3529  | 0.577  | 0.470 |
# | ground-track-field | 733   | 671   | 0.636  | 0.588 |
# | small-vehicle      | 58868 | 53141 | 0.759  | 0.692 |
# | large-vehicle      | 43075 | 40110 | 0.811  | 0.783 |
# | ship               | 76153 | 70008 | 0.842  | 0.797 |
# | tennis-court       | 5923  | 6001  | 0.968  | 0.907 |
# | basketball-court   | 1180  | 1260  | 0.895  | 0.796 |
# | storage-tank       | 13670 | 10718 | 0.703  | 0.710 |
# | soccer-ball-field  | 827   | 951   | 0.786  | 0.663 |
# | roundabout         | 973   | 1248  | 0.849  | 0.756 |
# | harbor             | 15468 | 12705 | 0.687  | 0.600 |
# | swimming-pool      | 3836  | 4123  | 0.864  | 0.783 |
# | helicopter         | 1189  | 1187  | 0.881  | 0.810 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.738 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.25 ==========
# 10/29 17:07:11 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:07:14,776] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:07:15,024] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:07:15,029] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:07:15,125] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:07:53 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18557 | 0.936  | 0.868 |
# | baseball-diamond   | 1087  | 1443  | 0.903  | 0.630 |
# | bridge             | 4183  | 3529  | 0.577  | 0.403 |
# | ground-track-field | 733   | 671   | 0.636  | 0.474 |
# | small-vehicle      | 58868 | 53141 | 0.759  | 0.631 |
# | large-vehicle      | 43075 | 40110 | 0.811  | 0.727 |
# | ship               | 76153 | 70008 | 0.842  | 0.759 |
# | tennis-court       | 5923  | 6001  | 0.968  | 0.875 |
# | basketball-court   | 1180  | 1260  | 0.895  | 0.712 |
# | storage-tank       | 13670 | 10718 | 0.703  | 0.666 |
# | soccer-ball-field  | 827   | 951   | 0.786  | 0.528 |
# | roundabout         | 973   | 1248  | 0.849  | 0.574 |
# | harbor             | 15468 | 12705 | 0.687  | 0.536 |
# | swimming-pool      | 3836  | 4123  | 0.864  | 0.663 |
# | helicopter         | 1189  | 1187  | 0.881  | 0.743 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.653 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.25 ==========
# 10/29 17:08:20 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 17:08:22,936] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:08:23,250] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:08:23,358] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 17:08:23,372] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 17:09:03 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# ...
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:09:27 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:09:30,693] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:09:30,935] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:09:30,948] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:09:31,002] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:09:51 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.636 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:10:13 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:10:16,601] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:10:16,911] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:10:16,915] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:10:16,978] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:10:35 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.636 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:10:57 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:11:00,843] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:01,050] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:01,095] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:01,157] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:11:20 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:11:44 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:11:46,721] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:47,073] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:47,105] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:11:47,146] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:12:07 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.636 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:12:30 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:12:33,060] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:12:33,290] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:12:33,386] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:12:33,395] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:12:51 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:13:13 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:13:16,244] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:13:16,433] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:13:16,455] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:13:16,540] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:13:36 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:13:58 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:14:02,106] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:02,234] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:02,568] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:02,662] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:14:20 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
# ========== score threshold=0.7 ==========
# 10/29 18:14:43 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2024-10-29 18:14:46,254] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:46,486] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:46,503] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-10-29 18:14:46,570] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 10/29 18:15:05 - mmengine - INFO -
# +--------------------+-------+------+--------+-------+
# | class              | gts   | dets | recall | ap    |
# +--------------------+-------+------+--------+-------+
# | plane              | 18788 | 3810 | 0.202  | 0.272 |
# | baseball-diamond   | 1087  | 0    | 0.000  | 0.000 |
# | bridge             | 4183  | 0    | 0.000  | 0.000 |
# | ground-track-field | 733   | 0    | 0.000  | 0.000 |
# | small-vehicle      | 58868 | 0    | 0.000  | 0.000 |
# | large-vehicle      | 43075 | 16   | 0.000  | 0.091 |
# | ship               | 76153 | 82   | 0.001  | 0.091 |
# | tennis-court       | 5923  | 3773 | 0.636  | 0.635 |
# | basketball-court   | 1180  | 0    | 0.000  | 0.000 |
# | storage-tank       | 13670 | 614  | 0.045  | 0.091 |
# | soccer-ball-field  | 827   | 3    | 0.004  | 0.091 |
# | roundabout         | 973   | 93   | 0.096  | 0.091 |
# | harbor             | 15468 | 0    | 0.000  | 0.000 |
# | swimming-pool      | 3836  | 0    | 0.000  | 0.000 |
# | helicopter         | 1189  | 0    | 0.000  | 0.000 |
# +--------------------+-------+------+--------+-------+
# | mAP                |       |      |        | 0.091 |
# +--------------------+-------+------+--------+-------+
#          score         1    rnd:42   rnd:666  rnd:6666  rnd:66666  rnd:666666  \
# 0.10  0.796567  0.473128  0.485691  0.470060  0.475408   0.460204    0.494141
# 0.20  0.764042  0.627359  0.636019  0.637143  0.631079   0.629365    0.637885
# 0.25  0.737540  0.652667  0.658215  0.656413  0.653548   0.652213    0.654050
# 0.30  0.698156  0.648651  0.649108  0.649977  0.649677   0.649729    0.650873
# 0.35  0.639825  0.611792  0.611264  0.610505  0.612490   0.612733    0.612868
# 0.40  0.561349  0.547297  0.549103  0.545866  0.547176   0.548946    0.547503
# 0.50  0.353396  0.350561  0.350529  0.350633  0.350528   0.350815    0.350507
# 0.70  0.090824  0.090796  0.090824  0.090806  0.090823   0.090855    0.090807
#
#       rnd:2024  rnd:9968     rnd:0     rnd:1   rnd:123   rnd:max   rnd:min  \
# 0.10  0.475788  0.483125  0.480347  0.480462  0.464385  0.494141  0.460204
# 0.20  0.629501  0.633367  0.632105  0.631837  0.628300  0.637885  0.628300
# 0.25  0.652948  0.655909  0.657424  0.654682  0.655362  0.658215  0.652213
# 0.30  0.649929  0.647674  0.649182  0.646568  0.650176  0.650873  0.646568
# 0.35  0.612854  0.611557  0.612209  0.608654  0.612766  0.612868  0.608654
# 0.40  0.545617  0.546607  0.547719  0.544401  0.548177  0.549103  0.544401
# 0.50  0.350540  0.350650  0.350393  0.350390  0.350664  0.350815  0.350390
# 0.70  0.090825  0.090811  0.090810  0.090800  0.090810  0.090855  0.090800
#
#       rnd:mean
# 0.10  0.476961
# 0.20  0.632660
# 0.25  0.655077
# 0.30  0.649289
# 0.35  0.611790
# 0.40  0.547112
# 0.50  0.350565
# 0.70  0.090817

# %%
for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
    random_values = [v for k, v in results[threshold].items() if k.startswith("rnd:")]
    # results[threshold]["rnd:mean"] = sum(random_values) / len(random_values)
    results[threshold]["rnd:std"] = sum((v - results[threshold]["rnd:mean"])**2 for v in random_values) / len(random_values)

df = pandas.DataFrame.from_dict(results).T
df.to_csv(os.path.join(save_root, model_name, 'results_trainval_score_threshold.csv'))
print(df)
# Out:
#          score         1    rnd:42   rnd:666  rnd:6666  rnd:66666  rnd:666666  \
# 0.10  0.796567  0.473128  0.485691  0.470060  0.475408   0.460204    0.494141
# 0.20  0.764042  0.627359  0.636019  0.637143  0.631079   0.629365    0.637885
# 0.25  0.737540  0.652667  0.658215  0.656413  0.653548   0.652213    0.654050
# 0.30  0.698156  0.648651  0.649108  0.649977  0.649677   0.649729    0.650873
# 0.35  0.639825  0.611792  0.611264  0.610505  0.612490   0.612733    0.612868
# 0.40  0.561349  0.547297  0.549103  0.545866  0.547176   0.548946    0.547503
# 0.50  0.353396  0.350561  0.350529  0.350633  0.350528   0.350815    0.350507
# 0.70  0.090824  0.090796  0.090824  0.090806  0.090823   0.090855    0.090807
#
#       rnd:2024  rnd:9968     rnd:0     rnd:1   rnd:123   rnd:max   rnd:min  \
# 0.10  0.475788  0.483125  0.480347  0.480462  0.464385  0.494141  0.460204
# 0.20  0.629501  0.633367  0.632105  0.631837  0.628300  0.637885  0.628300
# 0.25  0.652948  0.655909  0.657424  0.654682  0.655362  0.658215  0.652213
# 0.30  0.649929  0.647674  0.649182  0.646568  0.650176  0.650873  0.646568
# 0.35  0.612854  0.611557  0.612209  0.608654  0.612766  0.612868  0.608654
# 0.40  0.545617  0.546607  0.547719  0.544401  0.548177  0.549103  0.544401
# 0.50  0.350540  0.350650  0.350393  0.350390  0.350664  0.350815  0.350390
# 0.70  0.090825  0.090811  0.090810  0.090800  0.090810  0.090855  0.090800
#
#       rnd:mean   rnd:std
# 0.10  0.476961  0.016349
# 0.20  0.632660  0.028600
# 0.25  0.655077  0.030655
# 0.30  0.649289  0.030114
# 0.35  0.611790  0.026737
# 0.40  0.547112  0.021383
# 0.50  0.350565  0.008778
# 0.70  0.090817  0.000589

# %% [markdown]
# 说明随机性确实会影响结果，但是结果似乎没有造成很大的方差。有意思的是，效果最好时候（0.25阈值）的时候标准差最大，也就是最不稳定。但是每一列又是0.25的地方最好

# %% [markdown]
# 奇怪，这里还是有nms的，测试集在 merge results 的时候
#
# TODO：想想怎么解释下
# https://github.com/open-mmlab/mmrotate/blob/d50ab767fd0a6852e7931ac8e3a759f9605d659a/mmrotate/evaluation/metrics/dota_metric.py#L163-L172

# %% [markdown]
# ## 其他权重的测试集结果

# %%
# Downloaded checkpoints for DOTA dataset
tasks = (
    "rotated-fcos-le90_r50_fpn_1x_dota", 
    "rotated-retinanet-rbox-le90_r50_fpn_1x_dota",
    # "sasm-reppoints-qbox_r50_fpn_1x_dota",
    # "cfa-qbox_r50_fpn_1x_dota",
    # "r3det-oc_r50_fpn_1x_dota",
    # "rotated_atss_obb_r50_fpn_1x_dota_le90",
    # "rotated-faster-rcnn-le90_r50_fpn_1x_dota",
    # "oriented-rcnn-le90_r50_fpn_1x_dota",
    # "roi-trans-le90_r50_fpn_1x_dota",
    # "roi-trans-le90_swin-tiny_fpn_1x_dota",
)

import os
import mim
import pandas

import torch

from mmengine.fileio import load
from mmengine.config import Config
from mmengine.evaluator import DumpResults, Evaluator
from mmengine.runner import Runner

from mmrotate.evaluation import DOTAMetric
from mmrotate.utils import register_all_modules
from mmdet.utils import register_all_modules as register_all_modules_mmdet


def monkey_patch_of_collections_typehint_for_mmrotate1x():
    import collections
    from collections.abc import Mapping, Sequence, Iterable
    collections.Mapping = Mapping
    collections.Sequence = Sequence
    collections.Iterable = Iterable

monkey_patch_of_collections_typehint_for_mmrotate1x()

register_all_modules_mmdet(init_default_scope=False)
register_all_modules(init_default_scope=False)


def prepare_dota_evaluator():
    evaluator = Evaluator(DOTAMetric(metric="mAP"))
    evaluator.dataset_meta = {
        'classes':
        ('plane', 'baseball-diamond', 'bridge', 'ground-track-field',
         'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
         'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout',
         'harbor', 'swimming-pool', 'helicopter'),
    }
    return evaluator


def download_and_inference_pretrained_model(model_name, save_root):
    ckpt_fname = mim.download('mmrotate', [model_name], dest_root=os.path.join(save_root, model_name))[0]

    cfg_fpath = os.path.join(save_root, model_name, f'{model_name}.py')
    ckpt_fpath = os.path.join(save_root, model_name, ckpt_fname)

    cfg = Config.fromfile(cfg_fpath)
    cfg.launcher = "none"
    cfg.work_dir = save_root
    cfg.load_from = ckpt_fpath
    cfg.test_dataloader.dataset.data_root = "../playground/data/split_ss_dota"

    # inference on trainval set
    runner = Runner.from_cfg(cfg)
    runner.test_evaluator.metrics.append(
        DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_trainval.pkl')))
    runner.test()

    # inference on test set
    cfg.test_dataloader.dataset.ann_file = ''
    cfg.test_dataloader.dataset.data_prefix = dict(img_path='test/images/')
    cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.test_evaluator = dict(
        type='DOTAMetric',
        format_only=True,
        merge_patches=True,
        outfile_prefix=os.path.join(save_root, model_name, 'test'))
    runner = Runner.from_cfg(cfg)
    runner.test_evaluator.metrics.append(
        DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_test.pkl')))

    runner.test()
    

def get_trainval_results_of_different_settings(model_name, save_root):
    results = {}
    for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
        for hack_score in [True, False]:
            print("".join(["="*10, f" score threshold={threshold} ", "="*10]))

            evaluator = prepare_dota_evaluator()

            results_trainval = load(os.path.join(save_root, model_name, 'results_trainval.pkl'))   
            for res in results_trainval:
                keep = res["pred_instances"]["scores"] > threshold
                res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
                res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
                res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
                
                if hack_score:
                    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
                    
            map = evaluator.offline_evaluate(data_samples=results_trainval, chunk_size=128)['dota/mAP']
            
            if threshold not in results:
                results[threshold] = {}
            if hack_score:
                results[threshold]["score=1"] = map
            else:
                results[threshold]["score=score"] = map
                
    results = pandas.DataFrame.from_dict(results).T
    print(results)
    results.to_csv(os.path.join(save_root, model_name, 'results_trainval_score_threshold.csv'))
    return results
    
# for model_name in tasks:  # TODO: de-comment these lines to download and inference the pretrained model
#     save_root = f"./eval_mmrotate/{model_name}"
#     download_and_inference_pretrained_model(model_name, save_root)
    
for model_name in tasks:
    save_root = f"./eval_mmrotate/{model_name}"
    get_trainval_results_of_different_settings(model_name, save_root)
# Out:
# processing rotated-fcos-le90_r50_fpn_1x_dota...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Successfully downloaded rotated_fcos_r50_fpn_1x_dota_le90-d87568ed.pth to /home/lqy/florence-dota/scripts_py/eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota/rotated-fcos-le90_r50_fpn_1x_dota
# Successfully dumped rotated-fcos-le90_r50_fpn_1x_dota.py to /home/lqy/florence-dota/scripts_py/eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota/rotated-fcos-le90_r50_fpn_1x_dota
# 01/04 13:51:47 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul  5 2023, 18:54:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1500387243
#     GPU 0,1,2,3,4: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda-12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.5.0-1ubuntu1~22.04) 9.5.0
#     PyTorch: 2.3.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.0+cu121
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1500387243
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 01/04 13:51:48 - mmengine - INFO - Config:
# angle_version = 'le90'
# data_root = 'data/split_ss_dota/'
# dataset_type = 'DOTADataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'mmrotate'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(backend='disk')
# launcher = 'none'
# load_from = './eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota/rotated-fcos-le90_r50_fpn_1x_dota/rotated_fcos_r50_fpn_1x_dota_le90-d87568ed.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='mmdet.ResNet'),
#     bbox_head=dict(
#         bbox_coder=dict(angle_version='le90', type='DistanceAnglePointCoder'),
#         center_sample_radius=1.5,
#         center_sampling=True,
#         centerness_on_reg=True,
#         feat_channels=256,
#         in_channels=256,
#         loss_angle=None,
#         loss_bbox=dict(loss_weight=1.0, type='RotatedIoULoss'),
#         loss_centerness=dict(
#             loss_weight=1.0, type='mmdet.CrossEntropyLoss', use_sigmoid=True),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             type='mmdet.FocalLoss',
#             use_sigmoid=True),
#         norm_on_bbox=True,
#         num_classes=15,
#         scale_angle=True,
#         stacked_convs=4,
#         strides=[
#             8,
#             16,
#             32,
#             64,
#             128,
#         ],
#         type='RotatedFCOSHead',
#         use_hbbox_loss=False),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         boxtype2tensor=False,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='mmdet.DetDataPreprocessor'),
#     neck=dict(
#         add_extra_convs='on_output',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         relu_before_extra_convs=True,
#         start_level=1,
#         type='mmdet.FPN'),
#     test_cfg=dict(
#         max_per_img=2000,
#         min_bbox_size=0,
#         nms=dict(iou_threshold=0.1, type='nms_rotated'),
#         nms_pre=2000,
#         score_thr=0.05),
#     train_cfg=None,
#     type='mmdet.FCOS')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=35, norm_type=2),
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=500,
#         start_factor=0.3333333333333333,
#         type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='trainval/annfiles/',
#         data_prefix=dict(img_path='trainval/images/'),
#         data_root='../playground/data/split_ss_dota',
#         img_shape=(
#             1024,
#             1024,
#         ),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='mmdet.LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='mmdet.Resize'),
#             dict(
#                 box_type='qbox', type='mmdet.LoadAnnotations', with_bbox=True),
#             dict(
#                 box_type_mapping=dict(gt_bboxes='rbox'),
#                 type='ConvertBoxType'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='DOTADataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(metric='mAP', type='DOTAMetric')
# test_pipeline = [
#     dict(
#         file_client_args=dict(backend='disk'), type='mmdet.LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1024,
#         1024,
#     ), type='mmdet.Resize'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=12, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=None,
#     batch_size=2,
#     dataset=dict(
#         ann_file='trainval/annfiles/',
#         data_prefix=dict(img_path='trainval/images/'),
#         data_root='data/split_ss_dota/',
#         filter_cfg=dict(filter_empty_gt=True),
#         img_shape=(
#             1024,
#             1024,
#         ),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='mmdet.LoadImageFromFile'),
#             dict(
#                 box_type='qbox', type='mmdet.LoadAnnotations', with_bbox=True),
#             dict(
#                 box_type_mapping=dict(gt_bboxes='rbox'),
#                 type='ConvertBoxType'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='mmdet.Resize'),
#             dict(
#                 direction=[
#                     'horizontal',
#                     'vertical',
#                     'diagonal',
#                 ],
#                 prob=0.75,
#                 type='mmdet.RandomFlip'),
#             dict(type='mmdet.PackDetInputs'),
#         ],
#         type='DOTADataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(
#         file_client_args=dict(backend='disk'), type='mmdet.LoadImageFromFile'),
#     dict(box_type='qbox', type='mmdet.LoadAnnotations', with_bbox=True),
#     dict(box_type_mapping=dict(gt_bboxes='rbox'), type='ConvertBoxType'),
#     dict(keep_ratio=True, scale=(
#         1024,
#         1024,
#     ), type='mmdet.Resize'),
#     dict(
#         direction=[
#             'horizontal',
#             'vertical',
#             'diagonal',
#         ],
#         prob=0.75,
#         type='mmdet.RandomFlip'),
#     dict(type='mmdet.PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='trainval/annfiles/',
#         data_prefix=dict(img_path='trainval/images/'),
#         data_root='data/split_ss_dota/',
#         img_shape=(
#             1024,
#             1024,
#         ),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='mmdet.LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='mmdet.Resize'),
#             dict(
#                 box_type='qbox', type='mmdet.LoadAnnotations', with_bbox=True),
#             dict(
#                 box_type_mapping=dict(gt_bboxes='rbox'),
#                 type='ConvertBoxType'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='DOTADataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(metric='mAP', type='DOTAMetric')
# val_pipeline = [
#     dict(
#         file_client_args=dict(backend='disk'), type='mmdet.LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1024,
#         1024,
#     ), type='mmdet.Resize'),
#     dict(box_type='qbox', type='mmdet.LoadAnnotations', with_bbox=True),
#     dict(box_type_mapping=dict(gt_bboxes='rbox'), type='ConvertBoxType'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='RotLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota'
#
# 01/04 13:51:49 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 01/04 13:51:49 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 01/04 13:51:52 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: ./eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota/rotated-fcos-le90_r50_fpn_1x_dota/rotated_fcos_r50_fpn_1x_dota_le90-d87568ed.pth
# 01/04 13:51:52 - mmengine - INFO - Load checkpoint from ./eval_mmrotate/rotated-fcos-le90_r50_fpn_1x_dota/rotated-fcos-le90_r50_fpn_1x_dota/rotated_fcos_r50_fpn_1x_dota_le90-d87568ed.pth
# 01/04 13:51:53 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 01/04 13:51:53 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 01/04 13:51:53 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 01/04 13:51:53 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# /home/lqy/miniconda3/envs/florence/lib/python3.10/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 01/04 13:51:55 - mmengine - INFO - Epoch(test) [   50/21046]    eta: 0:23:09  time: 0.0662  data_time: 0.0181  memory: 434
# 01/04 13:51:56 - mmengine - INFO - Epoch(test) [  100/21046]    eta: 0:15:40  time: 0.0236  data_time: 0.0018  memory: 434
# 01/04 13:51:58 - mmengine - INFO - Epoch(test) [  150/21046]    eta: 0:12:54  time: 0.0213  data_time: 0.0017  memory: 434
# 01/04 13:51:59 - mmengine - INFO - Epoch(test) [  200/21046]    eta: 0:11:29  time: 0.0211  data_time: 0.0016  memory: 434
# 01/04 13:52:00 - mmengine - INFO - Epoch(test) [  250/21046]    eta: 0:10:36  time: 0.0207  data_time: 0.0015  memory: 434
# 01/04 13:52:01 - mmengine - INFO - Epoch(test) [  300/21046]    eta: 0:10:00  time: 0.0208  data_time: 0.0015  memory: 434
|
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.457 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.35 ==========
# 01/04 14:45:30 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:45:33,651] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:45:33,669] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:45:33,793] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:45:33,818] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:46:10 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19364 | 0.751  | 0.532 |
# | baseball-diamond   | 1087  | 1377  | 0.808  | 0.537 |
# | bridge             | 4183  | 3097  | 0.242  | 0.095 |
# | ground-track-field | 733   | 968   | 0.678  | 0.334 |
# | small-vehicle      | 58868 | 45842 | 0.393  | 0.235 |
# | large-vehicle      | 43075 | 29264 | 0.348  | 0.188 |
# | ship               | 76153 | 61539 | 0.459  | 0.283 |
# | tennis-court       | 5923  | 6149  | 0.757  | 0.557 |
# | basketball-court   | 1180  | 1232  | 0.655  | 0.439 |
# | storage-tank       | 13670 | 16888 | 0.584  | 0.315 |
# | soccer-ball-field  | 827   | 1017  | 0.513  | 0.255 |
# | roundabout         | 973   | 1209  | 0.787  | 0.497 |
# | harbor             | 15468 | 10514 | 0.367  | 0.240 |
# | swimming-pool      | 3836  | 4086  | 0.591  | 0.314 |
# | helicopter         | 1189  | 874   | 0.234  | 0.093 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.328 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.35 ==========
# 01/04 14:46:32 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:46:35,498] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:46:35,504] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:46:35,531] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:46:35,597] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:47:13 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 19364 | 0.751  | 0.617 |
# | baseball-diamond   | 1087  | 1377  | 0.808  | 0.727 |
# | bridge             | 4183  | 3097  | 0.242  | 0.206 |
# | ground-track-field | 733   | 968   | 0.678  | 0.558 |
# | small-vehicle      | 58868 | 45842 | 0.393  | 0.231 |
# | large-vehicle      | 43075 | 29264 | 0.348  | 0.262 |
# | ship               | 76153 | 61539 | 0.459  | 0.367 |
# | tennis-court       | 5923  | 6149  | 0.757  | 0.670 |
# | basketball-court   | 1180  | 1232  | 0.655  | 0.575 |
# | storage-tank       | 13670 | 16888 | 0.584  | 0.516 |
# | soccer-ball-field  | 827   | 1017  | 0.513  | 0.403 |
# | roundabout         | 973   | 1209  | 0.787  | 0.683 |
# | harbor             | 15468 | 10514 | 0.367  | 0.295 |
# | swimming-pool      | 3836  | 4086  | 0.591  | 0.463 |
# | helicopter         | 1189  | 874   | 0.234  | 0.177 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.450 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.4 ==========
# 01/04 14:47:35 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:47:38,187] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:47:38,249] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:47:38,334] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:47:38,422] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:48:13 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18869 | 0.747  | 0.543 |
# | baseball-diamond   | 1087  | 1250  | 0.798  | 0.517 |
# | bridge             | 4183  | 1951  | 0.210  | 0.173 |
# | ground-track-field | 733   | 824   | 0.659  | 0.421 |
# | small-vehicle      | 58868 | 40666 | 0.368  | 0.242 |
# | large-vehicle      | 43075 | 24025 | 0.309  | 0.242 |
# | ship               | 76153 | 55163 | 0.439  | 0.308 |
# | tennis-court       | 5923  | 5982  | 0.755  | 0.568 |
# | basketball-court   | 1180  | 1155  | 0.648  | 0.446 |
# | storage-tank       | 13670 | 13733 | 0.567  | 0.328 |
# | soccer-ball-field  | 827   | 843   | 0.484  | 0.221 |
# | roundabout         | 973   | 1094  | 0.774  | 0.525 |
# | harbor             | 15468 | 9055  | 0.343  | 0.252 |
# | swimming-pool      | 3836  | 3604  | 0.574  | 0.378 |
# | helicopter         | 1189  | 795   | 0.229  | 0.160 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.355 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.4 ==========
# 01/04 14:48:33 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:48:36,973] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:48:37,006] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:48:37,088] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:48:37,178] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:49:10 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18869 | 0.747  | 0.617 |
# | baseball-diamond   | 1087  | 1250  | 0.798  | 0.664 |
# | bridge             | 4183  | 1951  | 0.210  | 0.206 |
# | ground-track-field | 733   | 824   | 0.659  | 0.558 |
# | small-vehicle      | 58868 | 40666 | 0.368  | 0.231 |
# | large-vehicle      | 43075 | 24025 | 0.309  | 0.262 |
# | ship               | 76153 | 55163 | 0.439  | 0.367 |
# | tennis-court       | 5923  | 5982  | 0.755  | 0.670 |
# | basketball-court   | 1180  | 1155  | 0.648  | 0.575 |
# | storage-tank       | 13670 | 13733 | 0.567  | 0.516 |
# | soccer-ball-field  | 827   | 843   | 0.484  | 0.364 |
# | roundabout         | 973   | 1094  | 0.774  | 0.683 |
# | harbor             | 15468 | 9055  | 0.343  | 0.295 |
# | swimming-pool      | 3836  | 3604  | 0.574  | 0.463 |
# | helicopter         | 1189  | 795   | 0.229  | 0.177 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.443 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.5 ==========
# 01/04 14:49:31 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:49:34,721] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:49:34,979] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:49:35,038] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:49:35,176] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:50:04 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18158 | 0.739  | 0.578 |
# | baseball-diamond   | 1087  | 1043  | 0.746  | 0.587 |
# | bridge             | 4183  | 951   | 0.157  | 0.155 |
# | ground-track-field | 733   | 609   | 0.596  | 0.399 |
# | small-vehicle      | 58868 | 28545 | 0.286  | 0.198 |
# | large-vehicle      | 43075 | 15928 | 0.229  | 0.173 |
# | ship               | 76153 | 42955 | 0.383  | 0.273 |
# | tennis-court       | 5923  | 5737  | 0.748  | 0.583 |
# | basketball-court   | 1180  | 1027  | 0.628  | 0.485 |
# | storage-tank       | 13670 | 9777  | 0.527  | 0.430 |
# | soccer-ball-field  | 827   | 578   | 0.420  | 0.279 |
# | roundabout         | 973   | 890   | 0.717  | 0.598 |
# | harbor             | 15468 | 6666  | 0.288  | 0.214 |
# | swimming-pool      | 3836  | 2846  | 0.516  | 0.401 |
# | helicopter         | 1189  | 644   | 0.211  | 0.168 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.368 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.5 ==========
# 01/04 14:50:25 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:50:29,666] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:50:29,754] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:50:29,813] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:50:29,824] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:51:00 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 18158 | 0.739  | 0.617 |
# | baseball-diamond   | 1087  | 1043  | 0.746  | 0.664 |
# | bridge             | 4183  | 951   | 0.157  | 0.160 |
# | ground-track-field | 733   | 609   | 0.596  | 0.493 |
# | small-vehicle      | 58868 | 28545 | 0.286  | 0.178 |
# | large-vehicle      | 43075 | 15928 | 0.229  | 0.211 |
# | ship               | 76153 | 42955 | 0.383  | 0.307 |
# | tennis-court       | 5923  | 5737  | 0.748  | 0.670 |
# | basketball-court   | 1180  | 1027  | 0.628  | 0.575 |
# | storage-tank       | 13670 | 9777  | 0.527  | 0.516 |
# | soccer-ball-field  | 827   | 578   | 0.420  | 0.364 |
# | roundabout         | 973   | 890   | 0.717  | 0.683 |
# | harbor             | 15468 | 6666  | 0.288  | 0.236 |
# | swimming-pool      | 3836  | 2846  | 0.516  | 0.463 |
# | helicopter         | 1189  | 644   | 0.211  | 0.177 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.421 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.7 ==========
# 01/04 14:51:20 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:51:23,528] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:51:23,568] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:51:23,658] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:51:23,663] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:51:45 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 16858 | 0.710  | 0.595 |
# | baseball-diamond   | 1087  | 639   | 0.522  | 0.496 |
# | bridge             | 4183  | 284   | 0.057  | 0.091 |
# | ground-track-field | 733   | 303   | 0.349  | 0.324 |
# | small-vehicle      | 58868 | 3278  | 0.036  | 0.091 |
# | large-vehicle      | 43075 | 5892  | 0.093  | 0.069 |
# | ship               | 76153 | 21153 | 0.220  | 0.236 |
# | tennis-court       | 5923  | 5365  | 0.724  | 0.600 |
# | basketball-court   | 1180  | 836   | 0.554  | 0.457 |
# | storage-tank       | 13670 | 5321  | 0.368  | 0.348 |
# | soccer-ball-field  | 827   | 298   | 0.272  | 0.229 |
# | roundabout         | 973   | 546   | 0.520  | 0.517 |
# | harbor             | 15468 | 2751  | 0.142  | 0.145 |
# | swimming-pool      | 3836  | 657   | 0.149  | 0.171 |
# | helicopter         | 1189  | 310   | 0.130  | 0.140 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.301 |
# +--------------------+-------+-------+--------+-------+
# ========== score threshold=0.7 ==========
# 01/04 14:52:04 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 14:52:07,853] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:52:07,935] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:52:07,940] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 14:52:07,949] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 14:52:30 - mmengine - INFO -
# +--------------------+-------+-------+--------+-------+
# | class              | gts   | dets  | recall | ap    |
# +--------------------+-------+-------+--------+-------+
# | plane              | 18788 | 16858 | 0.710  | 0.617 |
# | baseball-diamond   | 1087  | 639   | 0.522  | 0.511 |
# | bridge             | 4183  | 284   | 0.057  | 0.091 |
# | ground-track-field | 733   | 303   | 0.349  | 0.345 |
# | small-vehicle      | 58868 | 3278  | 0.036  | 0.063 |
# | large-vehicle      | 43075 | 5892  | 0.093  | 0.091 |
# | ship               | 76153 | 21153 | 0.220  | 0.239 |
# | tennis-court       | 5923  | 5365  | 0.724  | 0.670 |
# | basketball-court   | 1180  | 836   | 0.554  | 0.507 |
# | storage-tank       | 13670 | 5321  | 0.368  | 0.358 |
# | soccer-ball-field  | 827   | 298   | 0.272  | 0.239 |
# | roundabout         | 973   | 546   | 0.520  | 0.530 |
# | harbor             | 15468 | 2751  | 0.142  | 0.166 |
# | swimming-pool      | 3836  | 657   | 0.149  | 0.173 |
# | helicopter         | 1189  | 310   | 0.130  | 0.139 |
# +--------------------+-------+-------+--------+-------+
# | mAP                |       |       |        | 0.316 |
# +--------------------+-------+-------+--------+-------+
#        score=1  score=score
# 0.10  0.132841     0.472324
# 0.20  0.249331     0.470236
# 0.25  0.282797     0.469500
# 0.30  0.306736     0.456575
# 0.35  0.327560     0.450055
# 0.40  0.354912     0.443270
# 0.50  0.368085     0.421019
# 0.70  0.300568     0.315942

# %%
# Downloaded checkpoints for DIOR dataset

tasks = (
    "rotated-retinanet-rbox-le90_r50_fpn_1x_dior", 
)

import os
import mim
import pandas

import torch

from mmengine.fileio import load
from mmengine.config import Config
from mmengine.evaluator import DumpResults, Evaluator
from mmengine.runner import Runner

from mmrotate.evaluation import DOTAMetric
from mmrotate.utils import register_all_modules
from mmdet.utils import register_all_modules as register_all_modules_mmdet


def monkey_patch_of_collections_typehint_for_mmrotate1x():
    import collections
    from collections.abc import Mapping, Sequence, Iterable
    collections.Mapping = Mapping
    collections.Sequence = Sequence
    collections.Iterable = Iterable

monkey_patch_of_collections_typehint_for_mmrotate1x()

register_all_modules_mmdet(init_default_scope=False)
register_all_modules(init_default_scope=False)


def prepare_evaluator():
    evaluator = Evaluator(DOTAMetric(metric="mAP"))
    evaluator.dataset_meta = {
        'classes':
        ('airplane', 'airport', 'baseballfield', 'basketballcourt', 'bridge',
         'chimney', 'expressway-service-area', 'expressway-toll-station',
         'dam', 'golffield', 'groundtrackfield', 'harbor', 'overpass', 'ship',
         'stadium', 'storagetank', 'tenniscourt', 'trainstation', 'vehicle', 'windmill'),
    }
    return evaluator


def download_and_inference_pretrained_model(model_name, save_root):
    ckpt_fname = mim.download('mmrotate', [model_name], dest_root=os.path.join(save_root, model_name))[0]

    cfg_fpath = os.path.join(save_root, model_name, f'{model_name}.py')
    ckpt_fpath = os.path.join(save_root, model_name, ckpt_fname)

    cfg = Config.fromfile(cfg_fpath)
    cfg.launcher = "none"
    cfg.work_dir = save_root
    cfg.load_from = ckpt_fpath
    cfg.val_dataloader.dataset.data_root = "../playground/data/DIOR"
    cfg.test_dataloader.dataset.data_root = "../playground/data/DIOR"

    # inference on test set
    runner = Runner.from_cfg(cfg)
    runner.test_evaluator.metrics.append(
        DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_test.pkl')))
    runner.test()

    # inference on trainval set
    cfg.test_dataloader = cfg.val_dataloader
    cfg.test_evaluator = cfg.val_evaluator
    runner = Runner.from_cfg(cfg)
    runner.test_evaluator.metrics.append(
        DumpResults(out_file_path=os.path.join(save_root, model_name, 'results_trainval.pkl')))
    runner.test()
    

def get_trainval_results_of_different_settings(model_name, save_root):
    results = {}
    for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
        for hack_score in [True, False]:
            print("".join(["="*10, f" score threshold={threshold} ", "="*10]))

            evaluator = prepare_evaluator()

            results_test = load(os.path.join(save_root, model_name, 'results_test.pkl'))   
            for res in results_test:
                keep = res["pred_instances"]["scores"] > threshold
                res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
                res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
                res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
                
                if hack_score:
                    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
                    
            map = evaluator.offline_evaluate(data_samples=results_test, chunk_size=128)['dota/mAP']
            
            if threshold not in results:
                results[threshold] = {}
            if hack_score:
                results[threshold]["score=1"] = map
            else:
                results[threshold]["score=score"] = map
                
    results = pandas.DataFrame.from_dict(results).T
    print(results)
    results.to_csv(os.path.join(save_root, model_name, 'results_test_score_threshold.csv'))
    return results
    
for model_name in tasks:  # TODO: de-comment these lines to download and inference the pretrained model
    save_root = f"./eval_mmrotate/{model_name}"
    download_and_inference_pretrained_model(model_name, save_root)
    
for model_name in tasks:
    save_root = f"./eval_mmrotate/{model_name}"
    get_trainval_results_of_different_settings(model_name, save_root)
# Out:
# ========== score threshold=0.1 ==========
# 01/04 16:43:05 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:43:08,228] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:08,268] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:08,299] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:08,334] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:43:29 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 7426  | 0.555  | 0.341 |
# | airport                 | 666   | 3264  | 0.339  | 0.051 |
# | baseballfield           | 3434  | 5778  | 0.771  | 0.355 |
# | basketballcourt         | 2146  | 6558  | 0.875  | 0.270 |
# | bridge                  | 2589  | 11077 | 0.349  | 0.031 |
# | chimney                 | 1031  | 3309  | 0.757  | 0.181 |
# | expressway-service-area | 1085  | 8550  | 0.811  | 0.088 |
# | expressway-toll-station | 688   | 3940  | 0.576  | 0.055 |
# | dam                     | 538   | 4410  | 0.396  | 0.031 |
# | golffield               | 575   | 3057  | 0.786  | 0.128 |
# | groundtrackfield        | 1885  | 6331  | 0.860  | 0.234 |
# | harbor                  | 3105  | 10747 | 0.426  | 0.076 |
# | overpass                | 1782  | 10050 | 0.520  | 0.072 |
# | ship                    | 35186 | 53374 | 0.808  | 0.482 |
# | stadium                 | 672   | 3071  | 0.801  | 0.146 |
# | storagetank             | 23361 | 41610 | 0.647  | 0.299 |
# | tenniscourt             | 7343  | 10441 | 0.852  | 0.510 |
# | trainstation            | 509   | 3894  | 0.637  | 0.074 |
# | vehicle                 | 26640 | 75326 | 0.477  | 0.103 |
# | windmill                | 2998  | 6308  | 0.754  | 0.322 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.193 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.1 ==========
# 01/04 16:43:44 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:43:47,682] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:47,746] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:47,844] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:43:47,846] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:44:09 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 7426  | 0.555  | 0.535 |
# | airport                 | 666   | 3264  | 0.339  | 0.174 |
# | baseballfield           | 3434  | 5778  | 0.771  | 0.704 |
# | basketballcourt         | 2146  | 6558  | 0.875  | 0.811 |
# | bridge                  | 2589  | 11077 | 0.349  | 0.130 |
# | chimney                 | 1031  | 3309  | 0.757  | 0.725 |
# | expressway-service-area | 1085  | 8550  | 0.811  | 0.674 |
# | expressway-toll-station | 688   | 3940  | 0.576  | 0.474 |
# | dam                     | 538   | 4410  | 0.396  | 0.202 |
# | golffield               | 575   | 3057  | 0.786  | 0.700 |
# | groundtrackfield        | 1885  | 6331  | 0.860  | 0.715 |
# | harbor                  | 3105  | 10747 | 0.426  | 0.317 |
# | overpass                | 1782  | 10050 | 0.520  | 0.324 |
# | ship                    | 35186 | 53374 | 0.808  | 0.757 |
# | stadium                 | 672   | 3071  | 0.801  | 0.664 |
# | storagetank             | 23361 | 41610 | 0.647  | 0.560 |
# | tenniscourt             | 7343  | 10441 | 0.852  | 0.810 |
# | trainstation            | 509   | 3894  | 0.637  | 0.460 |
# | vehicle                 | 26640 | 75326 | 0.477  | 0.374 |
# | windmill                | 2998  | 6308  | 0.754  | 0.630 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0
- mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 4378  | 0.496  | 0.432 |
# | airport                 | 666   | 260   | 0.153  | 0.082 |
# | baseballfield           | 3434  | 2574  | 0.662  | 0.576 |
# | basketballcourt         | 2146  | 2449  | 0.864  | 0.649 |
# | bridge                  | 2589  | 1127  | 0.156  | 0.125 |
# | chimney                 | 1031  | 860   | 0.738  | 0.668 |
# | expressway-service-area | 1085  | 1635  | 0.727  | 0.412 |
# | expressway-toll-station | 688   | 538   | 0.471  | 0.312 |
# | dam                     | 538   | 268   | 0.216  | 0.171 |
# | golffield               | 575   | 647   | 0.753  | 0.531 |
# | groundtrackfield        | 1885  | 2552  | 0.815  | 0.529 |
# | harbor                  | 3105  | 2381  | 0.355  | 0.189 |
# | overpass                | 1782  | 1475  | 0.351  | 0.211 |
# | ship                    | 35186 | 34803 | 0.767  | 0.587 |
# | stadium                 | 672   | 918   | 0.705  | 0.392 |
# | storagetank             | 23361 | 20049 | 0.584  | 0.409 |
# | tenniscourt             | 7343  | 6894  | 0.826  | 0.732 |
# | trainstation            | 509   | 564   | 0.528  | 0.312 |
# | vehicle                 | 26640 | 14280 | 0.346  | 0.270 |
# | windmill                | 2998  | 3374  | 0.730  | 0.473 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.403 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.25 ==========
# 01/04 16:46:03 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:46:06,387] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:06,487] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:06,517] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:06,604] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:46:23 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 4378  | 0.496  | 0.450 |
# | airport                 | 666   | 260   | 0.153  | 0.132 |
# | baseballfield           | 3434  | 2574  | 0.662  | 0.633 |
# | basketballcourt         | 2146  | 2449  | 0.864  | 0.811 |
# | bridge                  | 2589  | 1127  | 0.156  | 0.089 |
# | chimney                 | 1031  | 860   | 0.738  | 0.725 |
# | expressway-service-area | 1085  | 1635  | 0.727  | 0.660 |
# | expressway-toll-station | 688   | 538   | 0.471  | 0.438 |
# | dam                     | 538   | 268   | 0.216  | 0.180 |
# | golffield               | 575   | 647   | 0.753  | 0.700 |
# | groundtrackfield        | 1885  | 2552  | 0.815  | 0.715 |
# | harbor                  | 3105  | 2381  | 0.355  | 0.292 |
# | overpass                | 1782  | 1475  | 0.351  | 0.279 |
# | ship                    | 35186 | 34803 | 0.767  | 0.700 |
# | stadium                 | 672   | 918   | 0.705  | 0.648 |
# | storagetank             | 23361 | 20049 | 0.584  | 0.502 |
# | tenniscourt             | 7343  | 6894  | 0.826  | 0.810 |
# | trainstation            | 509   | 564   | 0.528  | 0.438 |
# | vehicle                 | 26640 | 14280 | 0.346  | 0.331 |
# | windmill                | 2998  | 3374  | 0.730  | 0.630 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.508 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.3 ==========
# 01/04 16:46:36 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:46:39,051] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:39,068] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:39,180] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:46:39,216] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:46:56 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 4200  | 0.482  | 0.435 |
# | airport                 | 666   | 144   | 0.095  | 0.045 |
# | baseballfield           | 3434  | 2403  | 0.645  | 0.591 |
# | basketballcourt         | 2146  | 2232  | 0.860  | 0.700 |
# | bridge                  | 2589  | 712   | 0.113  | 0.079 |
# | chimney                 | 1031  | 825   | 0.734  | 0.685 |
# | expressway-service-area | 1085  | 1244  | 0.688  | 0.424 |
# | expressway-toll-station | 688   | 433   | 0.446  | 0.338 |
# | dam                     | 538   | 137   | 0.123  | 0.100 |
# | golffield               | 575   | 550   | 0.736  | 0.602 |
# | groundtrackfield        | 1885  | 2340  | 0.803  | 0.571 |
# | harbor                  | 3105  | 1835  | 0.325  | 0.242 |
# | overpass                | 1782  | 1043  | 0.306  | 0.239 |
# | ship                    | 35186 | 31801 | 0.741  | 0.616 |
# | stadium                 | 672   | 778   | 0.680  | 0.420 |
# | storagetank             | 23361 | 17019 | 0.541  | 0.437 |
# | tenniscourt             | 7343  | 6592  | 0.816  | 0.753 |
# | trainstation            | 509   | 404   | 0.479  | 0.284 |
# | vehicle                 | 26640 | 10611 | 0.300  | 0.229 |
# | windmill                | 2998  | 3131  | 0.715  | 0.530 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.416 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.3 ==========
# 01/04 16:47:07 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:47:10,995] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:11,191] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:11,230] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:11,342] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:47:27 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 4200  | 0.482  | 0.450 |
# | airport                 | 666   | 144   | 0.095  | 0.091 |
# | baseballfield           | 3434  | 2403  | 0.645  | 0.633 |
# | basketballcourt         | 2146  | 2232  | 0.860  | 0.811 |
# | bridge                  | 2589  | 712   | 0.113  | 0.089 |
# | chimney                 | 1031  | 825   | 0.734  | 0.725 |
# | expressway-service-area | 1085  | 1244  | 0.688  | 0.609 |
# | expressway-toll-station | 688   | 433   | 0.446  | 0.438 |
# | dam                     | 538   | 137   | 0.123  | 0.139 |
# | golffield               | 575   | 550   | 0.736  | 0.700 |
# | groundtrackfield        | 1885  | 2340  | 0.803  | 0.715 |
# | harbor                  | 3105  | 1835  | 0.325  | 0.292 |
# | overpass                | 1782  | 1043  | 0.306  | 0.279 |
# | ship                    | 35186 | 31801 | 0.741  | 0.700 |
# | stadium                 | 672   | 778   | 0.680  | 0.600 |
# | storagetank             | 23361 | 17019 | 0.541  | 0.502 |
# | tenniscourt             | 7343  | 6592  | 0.816  | 0.810 |
# | trainstation            | 509   | 404   | 0.479  | 0.385 |
# | vehicle                 | 26640 | 10611 | 0.300  | 0.262 |
# | windmill                | 2998  | 3131  | 0.715  | 0.630 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.493 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.35 ==========
# 01/04 16:47:39 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:47:42,429] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:42,511] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:42,525] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:47:42,577] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:47:58 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 4051  | 0.470  | 0.439 |
# | airport                 | 666   | 72    | 0.062  | 0.055 |
# | baseballfield           | 3434  | 2292  | 0.631  | 0.609 |
# | basketballcourt         | 2146  | 2113  | 0.856  | 0.729 |
# | bridge                  | 2589  | 496   | 0.085  | 0.091 |
# | chimney                 | 1031  | 806   | 0.733  | 0.695 |
# | expressway-service-area | 1085  | 994   | 0.655  | 0.483 |
# | expressway-toll-station | 688   | 370   | 0.430  | 0.374 |
# | dam                     | 538   | 71    | 0.074  | 0.091 |
# | golffield               | 575   | 514   | 0.720  | 0.624 |
# | groundtrackfield        | 1885  | 2184  | 0.790  | 0.535 |
# | harbor                  | 3105  | 1445  | 0.289  | 0.205 |
# | overpass                | 1782  | 785   | 0.263  | 0.203 |
# | ship                    | 35186 | 28906 | 0.704  | 0.639 |
# | stadium                 | 672   | 668   | 0.655  | 0.458 |
# | storagetank             | 23361 | 14222 | 0.481  | 0.386 |
# | tenniscourt             | 7343  | 6404  | 0.809  | 0.767 |
# | trainstation            | 509   | 312   | 0.411  | 0.348 |
# | vehicle                 | 26640 | 8144  | 0.253  | 0.229 |
# | windmill                | 2998  | 2879  | 0.696  | 0.477 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0
# | ship                    | 35186 | 19566 | 0.527  | 0.539 |
# | stadium                 | 672   | 473   | 0.570  | 0.529 |
# | storagetank             | 23361 | 8080  | 0.313  | 0.354 |
# | tenniscourt             | 7343  | 6042  | 0.787  | 0.725 |
# | trainstation            | 509   | 149   | 0.238  | 0.255 |
# | vehicle                 | 26640 | 4633  | 0.163  | 0.181 |
# | windmill                | 2998  | 2114  | 0.571  | 0.492 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.421 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.7 ==========
# 01/04 16:50:38 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:50:41,866] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:50:41,954] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:50:41,954] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:50:41,977] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:50:54 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 3319  | 0.394  | 0.357 |
# | airport                 | 666   | 0     | 0.000  | 0.000 |
# | baseballfield           | 3434  | 2016  | 0.579  | 0.539 |
# | basketballcourt         | 2146  | 1803  | 0.807  | 0.791 |
# | bridge                  | 2589  | 12    | 0.002  | 0.091 |
# | chimney                 | 1031  | 743   | 0.708  | 0.717 |
# | expressway-service-area | 1085  | 383   | 0.343  | 0.356 |
# | expressway-toll-station | 688   | 219   | 0.307  | 0.355 |
# | dam                     | 538   | 0     | 0.000  | 0.000 |
# | golffield               | 575   | 340   | 0.555  | 0.519 |
# | groundtrackfield        | 1885  | 1441  | 0.616  | 0.539 |
# | harbor                  | 3105  | 50    | 0.015  | 0.091 |
# | overpass                | 1782  | 68    | 0.036  | 0.091 |
# | ship                    | 35186 | 13067 | 0.367  | 0.361 |
# | stadium                 | 672   | 321   | 0.443  | 0.430 |
# | storagetank             | 23361 | 4289  | 0.181  | 0.181 |
# | tenniscourt             | 7343  | 5717  | 0.757  | 0.713 |
# | trainstation            | 509   | 40    | 0.073  | 0.091 |
# | vehicle                 | 26640 | 3614  | 0.132  | 0.179 |
# | windmill                | 2998  | 749   | 0.225  | 0.258 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.333 |
# +-------------------------+-------+-------+--------+-------+
# ========== score threshold=0.7 ==========
# 01/04 16:51:06 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# [2025-01-04 16:51:09,539] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:51:09,603] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:51:09,611] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-01-04 16:51:09,654] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 01/04 16:51:21 - mmengine - INFO -
# +-------------------------+-------+-------+--------+-------+
# | class                   | gts   | dets  | recall | ap    |
# +-------------------------+-------+-------+--------+-------+
# | airplane                | 8212  | 3319  | 0.394  | 0.362 |
# | airport                 | 666   | 0     | 0.000  | 0.000 |
# | baseballfield           | 3434  | 2016  | 0.579  | 0.545 |
# | basketballcourt         | 2146  | 1803  | 0.807  | 0.811 |
# | bridge                  | 2589  | 12    | 0.002  | 0.045 |
# | chimney                 | 1031  | 743   | 0.708  | 0.725 |
# | expressway-service-area | 1085  | 383   | 0.343  | 0.360 |
# | expressway-toll-station | 688   | 219   | 0.307  | 0.358 |
# | dam                     | 538   | 0     | 0.000  | 0.000 |
# | golffield               | 575   | 340   | 0.555  | 0.538 |
# | groundtrackfield        | 1885  | 1441  | 0.616  | 0.586 |
# | harbor                  | 3105  | 50    | 0.015  | 0.091 |
# | overpass                | 1782  | 68    | 0.036  | 0.091 |
# | ship                    | 35186 | 13067 | 0.367  | 0.362 |
# | stadium                 | 672   | 321   | 0.443  | 0.449 |
# | storagetank             | 23361 | 4289  | 0.181  | 0.182 |
# | tenniscourt             | 7343  | 5717  | 0.757  | 0.725 |
# | trainstation            | 509   | 40    | 0.073  | 0.091 |
# | vehicle                 | 26640 | 3614  | 0.132  | 0.181 |
# | windmill                | 2998  | 749   | 0.225  | 0.257 |
# +-------------------------+-------+-------+--------+-------+
# | mAP                     |       |       |        | 0.338 |
# +-------------------------+-------+-------+--------+-------+
#        score=1  score=score
# 0.10  0.192534     0.536925
# 0.20  0.360655     0.519671
# 0.25  0.403133     0.508146
# 0.30  0.415944     0.493018
# 0.35  0.421802     0.473736
# 0.40  0.425670     0.466705
# 0.50  0.399833     0.421424
# 0.70  0.332957     0.337894

# %%
# Checkpoints trained on localhost

tasks = (
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_dior-2",
        cfg_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_dior-2/rotated-fcos-le90_r50_fpn_1x_dior.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_dior-2/epoch_12.pth",
    ), 
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_fair",
        cfg_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_fair/rotated-fcos-le90_r50_fpn_1x_fair.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_fair/epoch_12.pth",
    ),
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota",
        cfg_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota/rotated-retinanet-rbox-le90_r50_fpn_1x_dota.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota/epoch_12.pth",
    ), 
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_fair",
        cfg_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_fair/rotated-retinanet-rbox-le90_r50_fpn_1x_fair.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_fair/epoch_12.pth",
    ),
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_6x_srsdd",
        cfg_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_6x_srsdd/rotated-fcos-le90_r50_fpn_6x_srsdd.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_6x_srsdd/epoch_72.pth",
    ), 
    dict(
        work_dir="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_6x_srsdd",
        cfg_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_6x_srsdd/rotated-retinanet-rbox-le90_r50_fpn_6x_srsdd.py",
        ckpt_fpath="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_6x_srsdd/epoch_72.pth",
    ),
)

import os
import mim
import pandas

import torch

from mmengine.fileio import load
from mmengine.config import Config
from mmengine.evaluator import DumpResults, Evaluator
from mmengine.runner import Runner

from mmrotate.utils import register_all_modules
from mmdet.utils import register_all_modules as register_all_modules_mmdet


def monkey_patch_of_collections_typehint_for_mmrotate1x():
    import collections
    from collections.abc import Mapping, Sequence, Iterable
    collections.Mapping = Mapping
    collections.Sequence = Sequence
    collections.Iterable = Iterable

monkey_patch_of_collections_typehint_for_mmrotate1x()

register_all_modules_mmdet(init_default_scope=False)
register_all_modules(init_default_scope=False)


def prepare_evaluator(dataset_name):
    if dataset_name == "dota":
        from mmrotate.evaluation import DOTAMetric
        evaluator = Evaluator(DOTAMetric(metric="mAP"))
        evaluator.dataset_meta = {
            'classes':
            ('plane', 'baseball-diamond', 'bridge', 'ground-track-field',
             'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
             'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout',
             'harbor', 'swimming-pool', 'helicopter'),
        }
    elif dataset_name == "fair":
        from lmmrotate.modules.fair_metric import FAIRMetric
        evaluator = Evaluator(FAIRMetric(metric="mAP"))
        evaluator.dataset_meta = {
            'classes':
            ('Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'C919', 'A220',
            'A321', 'A330', 'A350', 'ARJ21', 'Passenger Ship', 'Motorboat',
            'Fishing Boat', 'Tugboat', 'Engineering Ship', 'Liquid Cargo Ship',
            'Dry Cargo Ship', 'Warship', 'Small Car', 'Bus', 'Cargo Truck',
            'Dump Truck', 'Van', 'Trailer', 'Tractor', 'Excavator',
            'Truck Tractor', 'Basketball Court', 'Tennis Court', 'Football Field',
            'Baseball Field', 'Intersection', 'Roundabout', 'Bridge'),
        }
    elif dataset_name == "dior":
        from mmrotate.evaluation import DOTAMetric
        evaluator = Evaluator(DOTAMetric(metric="mAP"))
        evaluator.dataset_meta = {
            'classes':
            ('airplane', 'airport', 'baseballfield', 'basketballcourt', 'bridge',
             'chimney', 'expressway-service-area', 'expressway-toll-station',
             'dam', 'golffield', 'groundtrackfield', 'harbor', 'overpass', 'ship',
             'stadium', 'storagetank', 'tenniscourt', 'trainstation', 'vehicle', 'windmill'),
        }
    elif dataset_name == "srsdd":
        from mmrotate.evaluation import RotatedCocoMetric
        evaluator = Evaluator(RotatedCocoMetric(metric='bbox', classwise=True))
        evaluator.dataset_meta = {
            'classes':
            ('Cell-Container', 'Container', 'Dredger', 'Fishing', 'LawEnforce', 'ore-oil'),
        }
    return evaluator


def inference_localhost_model(cfg_fpath, ckpt_fpath, work_dir, **kwargs):
    cfg = Config.fromfile(cfg_fpath)
    cfg.launcher = "none"
    cfg.load_from = ckpt_fpath
    cfg.val_dataloader.dataset.data_root = os.path.join("../", cfg.val_dataloader.dataset.data_root)
    cfg.test_dataloader.dataset.data_root = os.path.join("../", cfg.test_dataloader.dataset.data_root)

    if "dior" in cfg_fpath or "srsdd" in cfg_fpath:
        # inference on test set
        runner = Runner.from_cfg(cfg)
        runner.test_evaluator.metrics.append(
            DumpResults(out_file_path=os.path.join(work_dir, 'results_test.pkl')))
        runner.test()

    elif "fair" in cfg_fpath:
        from lmmrotate.modules.fair_dataset import FAIRDOTADataset
        from lmmrotate.modules.fair_metric import FAIRMetric

        # inference on test set
        cfg.test_evaluator.outfile_prefix = os.path.join(work_dir, 'test')
        runner = Runner.from_cfg(cfg)
        runner.test_evaluator.metrics.append(
            DumpResults(out_file_path=os.path.join(work_dir, 'results_test.pkl')))
        runner.test()

        # inference on trainval set
        cfg.test_dataloader = cfg.val_dataloader
        cfg.test_evaluator = cfg.val_evaluator
        runner = Runner.from_cfg(cfg)
        runner.test_evaluator.metrics.append(
            DumpResults(out_file_path=os.path.join(work_dir, 'results_trainval.pkl')))
        runner.test()

    elif "dota" in cfg_fpath:
        # inference on trainval set
        runner = Runner.from_cfg(cfg)
        runner.test_evaluator.metrics.append(
            DumpResults(out_file_path=os.path.join(work_dir, 'results_trainval.pkl')))
        runner.test()

        # inference on test set
        cfg.test_dataloader.dataset.ann_file = ''
        cfg.test_dataloader.dataset.data_prefix = dict(img_path='test/images/')
        cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline
        cfg.test_evaluator = dict(
            type='DOTAMetric',
            format_only=True,
            merge_patches=True,
            outfile_prefix=os.path.join(work_dir, 'test', 'dota_Task1'))
        runner = Runner.from_cfg(cfg)
        runner.test_evaluator.metrics.append(
            DumpResults(out_file_path=os.path.join(work_dir, 'results_test.pkl')))
        runner.test()
    else:
        raise NotImplementedError
    

def get_results_of_different_settings(work_dir, **kwargs):
    results = {}

    if "dior" in work_dir:
        split, dataset_name = "test", "dior"
    elif "srsdd" in work_dir:
        split, dataset_name = "test", "srsdd"
    elif "fair" in work_dir:
        split, dataset_name = "trainval", "fair"
    elif "dota" in work_dir:
        split, dataset_name = "trainval", "dota"
    else:
        raise NotImplementedError

    for threshold in (0.1, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.7):
        for hack_score in [True, False]:
            print("".join(["="*10, f" score threshold={threshold} ", "="*10]))

            evaluator = prepare_evaluator(dataset_name)

            results_test = load(os.path.join(work_dir, f'results_{split}.pkl'))   
            for res in results_test:
                keep = res["pred_instances"]["scores"] > threshold
                res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
                res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
                res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
                
                if hack_score:
                    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
                    
            mAP = evaluator.offline_evaluate(data_samples=results_test, chunk_size=128)
            # import ipdb; ipdb.set_trace()
            mAP = mAP.get('dota/mAP', mAP.get('fair1m/mAP', mAP.get('r_coco/bbox_mAP_50')))
            
            if threshold not in results:
                results[threshold] = {}
            if hack_score:
                results[threshold]["score=1"] = mAP
            else:
                results[threshold]["score=score"] = mAP
                
    results = pandas.DataFrame.from_dict(results).T
    print(results)
    results.to_csv(os.path.join(work_dir, f'results_{split}_score_threshold.csv'))
    return results
    

for task in tasks:  # TODO: de-comment these lines to inference the trained model
    inference_localhost_model(**task)
    
for task in tasks:
    get_results_of_different_settings(**task)

# %%
from mmrotate.evaluation import DOTAMetric
work_dir = "../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota"
cfg_fpath = "../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota/rotated-retinanet-rbox-le90_r50_fpn_1x_dota.py"
ckpt_fpath = "../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_dota/epoch_12.pth"

evaluator = Evaluator(
    DOTAMetric(format_only=True, merge_patches=True, outfile_prefix=os.path.join(work_dir, 'test_0.35above-score=1'))
)

evaluator.dataset_meta = {
    'classes':
    ('plane', 'baseball-diamond', 'bridge', 'ground-track-field',
    'small-vehicle', 'large-vehicle', 'ship', 'tennis-court',
    'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout',
    'harbor', 'swimming-pool', 'helicopter'),
}

results_test = load(os.path.join(work_dir, 'results_test.pkl'))   
for res in results_test:
    keep = res["pred_instances"]["scores"] > 0.35
    res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
    res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
    res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
    res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
    
evaluator.offline_evaluate(data_samples=results_test, chunk_size=128)

# %%
tasks = (
    dict(work_dir="../playground/mmrotate_workdir/rotated-fcos-le90_r50_fpn_1x_fair"),
    dict(work_dir="../playground/mmrotate_workdir/rotated-retinanet-rbox-le90_r50_fpn_1x_fair"),
)

def eval_for_fair(work_dir, **kwargs):
    if "fcos" in work_dir:
        threshold = 0.25
    elif "retinanet" in work_dir:
        threshold = 0.35
    else:
        raise NotImplementedError

    evaluator = Evaluator(
        DOTAMetric(format_only=True, merge_patches=True, outfile_prefix=os.path.join(work_dir, f'test_{threshold}above-score=1'))
    )

    evaluator.dataset_meta = {
        'classes':
        ('Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'C919', 'A220',
         'A321', 'A330', 'A350', 'ARJ21', 'Passenger Ship', 'Motorboat',
         'Fishing Boat', 'Tugboat', 'Engineering Ship', 'Liquid Cargo Ship',
         'Dry Cargo Ship', 'Warship', 'Small Car', 'Bus', 'Cargo Truck',
         'Dump Truck', 'Van', 'Trailer', 'Tractor', 'Excavator',
         'Truck Tractor', 'Basketball Court', 'Tennis Court', 'Football Field',
         'Baseball Field', 'Intersection', 'Roundabout', 'Bridge'),
    }

    results_test = load(os.path.join(work_dir, 'results_test.pkl'))   
    for res in results_test:
        keep = res["pred_instances"]["scores"] > threshold
        res["pred_instances"]["scores"] = res["pred_instances"]["scores"][keep]
        res["pred_instances"]["labels"] = res["pred_instances"]["labels"][keep]
        res["pred_instances"]["bboxes"] = res["pred_instances"]["bboxes"][keep]
        res["pred_instances"]["scores"] = torch.ones_like(res["pred_instances"]["scores"])
        
    evaluator.offline_evaluate(data_samples=results_test, chunk_size=128)

for task in tasks:
    eval_for_fair(**task)
